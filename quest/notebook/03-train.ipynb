# %%
import sys
sys.path.insert(0,'..')
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# %load_ext autoreload
# %autosave 180
# Out:
# Autosaving every 180 seconds

# %%
import pandas as pd
import numpy as np
import os
import tensorflow.keras as keras
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from source.version3.data import dataLoader
from source.version3.model import BERTModel

# %%
def train(fold):
    train, valid = dataLoader(fold)
    model = BERTModel()
    path = '../../model/version-3/fold-{}/model.pt'.format(fold)
    weights = ModelCheckpoint(path, save_best_only=True, monitor='val_loss', mode='min', verbose=0)
    schedule = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=1, verbose=0, mode='min')
    params = {}
    params['generator'] = train
    params['epochs'] = 4
    params['verbose'] = 1
    params['shuffle'] = True
    params['callbacks'] = [weights, schedule]
    params['validation_data'] = valid
    model.fit_generator(**params)
    del model
    K.clear_session()
    return None

# %%
train(6)

# %%
train(1)
# Out:
# WARNING:tensorflow:From <ipython-input-3-458054349133>:14: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 4863 steps, validate for 1216 steps
# Epoch 1/4
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 4862/4863 [============================>.] - ETA: 0s - loss: 0.3913WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: ../../model/version-3/fold-1/model.pt/assets
# 4863/4863 [==============================] - 1085s 223ms/step - loss: 0.3913 - val_loss: 0.3824
# Epoch 2/4
# 4862/4863 [============================>.] - ETA: 0s - loss: 0.3645INFO:tensorflow:Assets written to: ../../model/version-3/fold-1/model.pt/assets
# 4863/4863 [==============================] - 1061s 218ms/step - loss: 0.3645 - val_loss: 0.3697
# Epoch 3/4
# 4863/4863 [==============================] - 1027s 211ms/step - loss: 0.3493 - val_loss: 0.3734
# Epoch 4/4
# 4863/4863 [==============================] - 1027s 211ms/step - loss: 0.3283 - val_loss: 0.3748

# %%
train(2)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 4863 steps, validate for 1216 steps
# Epoch 1/4
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 4862/4863 [============================>.] - ETA: 0s - loss: 0.3951INFO:tensorflow:Assets written to: ../../model/version-3/fold-2/model.pt/assets
# 4863/4863 [==============================] - 1085s 223ms/step - loss: 0.3951 - val_loss: 0.3766
# Epoch 2/4
# 4862/4863 [============================>.] - ETA: 0s - loss: 0.3655INFO:tensorflow:Assets written to: ../../model/version-3/fold-2/model.pt/assets
# 4863/4863 [==============================] - 1059s 218ms/step - loss: 0.3655 - val_loss: 0.3711
# Epoch 3/4
# 4863/4863 [==============================] - 1026s 211ms/step - loss: 0.3509 - val_loss: 0.3722
# Epoch 4/4
# 4863/4863 [==============================] - 1026s 211ms/step - loss: 0.3298 - val_loss: 0.3716

# %%
train(3)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 4863 steps, validate for 1216 steps
# Epoch 1/4
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 4862/4863 [============================>.] - ETA: 0s - loss: 0.3939INFO:tensorflow:Assets written to: ../../model/version-3/fold-3/model.pt/assets
# 4863/4863 [==============================] - 1089s 224ms/step - loss: 0.3939 - val_loss: 0.3771
# Epoch 2/4
# 4862/4863 [============================>.] - ETA: 0s - loss: 0.3657INFO:tensorflow:Assets written to: ../../model/version-3/fold-3/model.pt/assets
# 4863/4863 [==============================] - 1068s 220ms/step - loss: 0.3657 - val_loss: 0.3662
# Epoch 3/4
# 4863/4863 [==============================] - 1031s 212ms/step - loss: 0.3510 - val_loss: 0.3682
# Epoch 4/4
# 4863/4863 [==============================] - 1031s 212ms/step - loss: 0.3292 - val_loss: 0.3707

# %%
train(4)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 4863 steps, validate for 1216 steps
# Epoch 1/4
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 4862/4863 [============================>.] - ETA: 0s - loss: 0.3921INFO:tensorflow:Assets written to: ../../model/version-3/fold-4/model.pt/assets
# 4863/4863 [==============================] - 1089s 224ms/step - loss: 0.3921 - val_loss: 0.3693
# Epoch 2/4
# 4862/4863 [============================>.] - ETA: 0s - loss: 0.3651INFO:tensorflow:Assets written to: ../../model/version-3/fold-4/model.pt/assets
# 4863/4863 [==============================] - 1063s 219ms/step - loss: 0.3651 - val_loss: 0.3641
# Epoch 3/4
# 4863/4863 [==============================] - 1029s 212ms/step - loss: 0.3511 - val_loss: 0.3699
# Epoch 4/4
# 4863/4863 [==============================] - 1029s 212ms/step - loss: 0.3303 - val_loss: 0.3667

# %%
train(5)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 4864 steps, validate for 1215 steps
# Epoch 1/4
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss.
# 4863/4864 [============================>.] - ETA: 0s - loss: 0.3927INFO:tensorflow:Assets written to: ../../model/version-3/fold-5/model.pt/assets
# 4864/4864 [==============================] - 1088s 224ms/step - loss: 0.3927 - val_loss: 0.3727
# Epoch 2/4
# 4864/4864 [==============================] - 1028s 211ms/step - loss: 0.3643 - val_loss: 0.3742
# Epoch 3/4
# 4863/4864 [============================>.] - ETA: 0s - loss: 0.3441INFO:tensorflow:Assets written to: ../../model/version-3/fold-5/model.pt/assets
# 4864/4864 [==============================] - 1062s 218ms/step - loss: 0.3441 - val_loss: 0.3693
# Epoch 4/4
# 4863/4864 [============================>.] - ETA: 0s - loss: 0.3392
