# %%
import sys
sys.path.insert(0,'..')
# %load_ext autoreload
# %autosave 180
# Out:
# Autosaving every 180 seconds

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from apex import amp
from torch.optim.lr_scheduler import ReduceLROnPlateau
from transformers.optimization import AdamW
from source.version4.data import dataLoader
from source.version4.model import Model
from source.version4.train import trainModel
from source.version4.loss import Loss

# %%
def train(fold):
    loader = {}
    loader['batch_size'] = 2
    loader['fold'] = fold
    train, valid = dataLoader(**loader)
    model = Model()
    model = model.to('cuda:0')
    optimizer = AdamW(model.parameters(), lr=1e-5, weight_decay=0.)
    model, optimizer = amp.initialize(model, optimizer, opt_level="O2", keep_batchnorm_fp32=True, verbosity=0)
    schedular = ReduceLROnPlateau(optimizer, factor=0.5, min_lr=1e-7, patience=1)
    trainer = {}
    trainer['model'] = model
    trainer['train'] = train
    trainer['valid'] = valid
    trainer['loss_fn'] = Loss()
    trainer['optimizer'] = optimizer
    trainer['save'] = '../../model/version-1/fold-{}/model.pt'.format(fold)
    trainer['epochs'] = 10
    trainer['batch'] = 2
    trainer['schedular'] = schedular
    trainModel(**trainer)
    model = model.cpu()
    del model
    return None

# %%
train(1)
# Out:
# 100%|██████████| 4862/4862 [11:06<00:00,  7.30it/s, train_loss=0.3412, valid_loss=-0.2536]
#  37%|███▋      | 1776/4862 [03:44<06:12,  8.28it/s, train_loss=0.2913]

# %%
train(2)

# %%
train(3)

# %%
train(4)

# %%
train(5)
