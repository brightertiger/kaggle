# %%
import pandas as pd
import numpy as np
from catboost import CatBoostClassifier, Pool

# %%
train_data = pd.read_csv('../data/model/train.csv')
train_labels = train_data['redemption_status'].values
train_data = train_data.drop(['id','customer_id','redemption_status'], axis=1)
valid_data = pd.read_csv('../data/model/valid.csv')
valid_labels = valid_data['redemption_status'].values
valid_data = valid_data.drop(['id','customer_id','redemption_status'], axis=1)
test_data = pd.read_csv('../data/model/test.csv')
score = test_data[['id']].copy()
test_data = test_data.drop(['id','customer_id'], axis=1)

# %%
train_data = Pool(train_data, train_labels)
valid_data = Pool(valid_data, valid_labels)
test_data = Pool(test_data)

# %%
params = {}
params['num_boost_round'] = 2000
params['max_depth'] = 5
params['learning_rate'] = 0.01
params['colsample_bylevel'] = 0.5
params['reg_lambda'] = 0.01
params['eval_metric'] = 'AUC'

# %%
model = CatBoostClassifier(**params)

# %%
model.fit(train_data, eval_set=[train_data, valid_data], early_stopping_rounds=200, verbose_eval=50)
# Out:
# 0:	test: 0.8016852	test1: 0.8049049	best: 0.8049049 (0)	total: 71.2ms	remaining: 2m 22s
# 50:	test: 0.9404594	test1: 0.9355023	best: 0.9358794 (49)	total: 980ms	remaining: 37.4s
# 100:	test: 0.9444334	test1: 0.9412828	best: 0.9414294 (97)	total: 1.88s	remaining: 35.3s
# 150:	test: 0.9477583	test1: 0.9456761	best: 0.9456761 (150)	total: 2.75s	remaining: 33.6s
# 200:	test: 0.9500869	test1: 0.9478537	best: 0.9478537 (200)	total: 3.63s	remaining: 32.5s
# 250:	test: 0.9535296	test1: 0.9505329	best: 0.9505621 (245)	total: 4.51s	remaining: 31.4s
# 300:	test: 0.9577269	test1: 0.9530787	best: 0.9530787 (300)	total: 5.38s	remaining: 30.4s
# 350:	test: 0.9607584	test1: 0.9549024	best: 0.9549024 (350)	total: 6.27s	remaining: 29.5s
# 400:	test: 0.9632089	test1: 0.9556348	best: 0.9556379 (384)	total: 7.16s	remaining: 28.6s
# 450:	test: 0.9648839	test1: 0.9561056	best: 0.9561486 (448)	total: 8.03s	remaining: 27.6s
# 500:	test: 0.9666103	test1: 0.9572018	best: 0.9572087 (495)	total: 8.92s	remaining: 26.7s
# 550:	test: 0.9681650	test1: 0.9578142	best: 0.9578142 (550)	total: 9.81s	remaining: 25.8s
# 600:	test: 0.9691922	test1: 0.9580946	best: 0.9581111 (596)	total: 10.7s	remaining: 24.9s
# 650:	test: 0.9706280	test1: 0.9586318	best: 0.9586478 (646)	total: 11.6s	remaining: 24s
# 700:	test: 0.9723653	test1: 0.9594171	best: 0.9594171 (700)	total: 12.4s	remaining: 23s
# 750:	test: 0.9732797	test1: 0.9595390	best: 0.9595390 (750)	total: 13.3s	remaining: 22.1s
# 800:	test: 0.9742222	test1: 0.9594560	best: 0.9595729 (756)	total: 14.2s	remaining: 21.2s
# 850:	test: 0.9750006	test1: 0.9595541	best: 0.9596189 (841)	total: 15.1s	remaining: 20.3s
# 900:	test: 0.9759180	test1: 0.9597608	best: 0.9597782 (897)	total: 15.9s	remaining: 19.4s
# 950:	test: 0.9768363	test1: 0.9600075	best: 0.9600250 (911)	total: 16.8s	remaining: 18.6s
# 1000:	test: 0.9779690	test1: 0.9603119	best: 0.9603119 (1000)	total: 17.7s	remaining: 17.7s
# 1050:	test: 0.9793238	test1: 0.9607719	best: 0.9607719 (1050)	total: 18.6s	remaining: 16.8s
# 1100:	test: 0.9801747	test1: 0.9610121	best: 0.9610121 (1100)	total: 19.4s	remaining: 15.9s
# 1150:	test: 0.9810072	test1: 0.9610076	best: 0.9611250 (1128)	total: 20.3s	remaining: 15s
# 1200:	test: 0.9819920	test1: 0.9613615	best: 0.9614538 (1186)	total: 21.2s	remaining: 14.1s
# 1250:	test: 0.9827942	test1: 0.9612792	best: 0.9614538 (1186)	total: 22.1s	remaining: 13.2s
# 1300:	test: 0.9834788	test1: 0.9610915	best: 0.9614538 (1186)	total: 23s	remaining: 12.3s
# 1350:	test: 0.9841158	test1: 0.9608336	best: 0.9614538 (1186)	total: 23.9s	remaining: 11.5s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.9614538377
# bestIteration = 1186
#
# Shrink model to first 1187 iterations.
