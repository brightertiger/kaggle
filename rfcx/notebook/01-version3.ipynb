# %%
import sys
sys.path.insert(0,'..')
from warnings import filterwarnings
filterwarnings("ignore")
# %load_ext autoreload
# %autosave 180
# Out:
# Autosaving every 180 seconds

# %%
# %autoreload
import os
import random
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
from torch.optim import Adam
from torch.utils.data import DataLoader
from source.version3.data import trainLoader
from source.version3.model import ResnetModel
from source.version3.train import trainModel
from source.version3.loss import CELoss
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
def seed(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True
    return None

seed(2017)

# %%
def train(fold):
    loader = {}
    loader['data'] = '../../data/positive.csv'
    loader['fold_idx'] = fold
    train, valid = trainLoader(**loader)
    params = {}
    params['batch_size'] = 8
    params['drop_last'] = True
    train = DataLoader(train, **params, num_workers=4, shuffle=True)
    valid = DataLoader(valid, **params, num_workers=0, shuffle=False)
    model = ResnetModel()
    model = model.to('cuda:0')
    optimizer = Adam(model.parameters(), lr=1e-04)
    schedular = ReduceLROnPlateau(optimizer, min_lr=1e-5, patience=0, factor=0.5)
    trainer = {}
    trainer['model'] = model
    trainer['train_data'] = train
    trainer['valid_data'] = valid
    trainer['loss_fn'] = nn.BCEWithLogitsLoss()
    trainer['optimizer'] = optimizer
    trainer['save_path'] = '../../model/version3/model_{}.pt'.format(fold)
    trainer['epochs'] = 15
    trainer['batch'] = 8
    trainer['scheduler'] = schedular
    trainModel(**trainer)
    model.cpu()
    del model
    return None

# %%
train(1)
# Out:
# Train Images: 972 Valid Images: 244
# 100% 968/968 [02:23<00:00,  6.75it/s, trn_ls=0.2341, val_ls=0.1412, val_mt=0.3750]
# 100% 968/968 [01:58<00:00,  8.17it/s, trn_ls=0.1249, val_ls=0.0976, val_mt=0.5792]
# 100% 968/968 [01:56<00:00,  8.28it/s, trn_ls=0.0958, val_ls=0.0748, val_mt=0.6792]
# 100% 968/968 [01:54<00:00,  8.43it/s, trn_ls=0.0779, val_ls=0.0661, val_mt=0.7292]
# 100% 968/968 [01:57<00:00,  8.21it/s, trn_ls=0.0682, val_ls=0.0770, val_mt=0.7250]
# 100% 968/968 [01:54<00:00,  8.48it/s, trn_ls=0.0523, val_ls=0.0471, val_mt=0.7958]
# 100% 968/968 [01:49<00:00,  8.88it/s, trn_ls=0.0438, val_ls=0.0509, val_mt=0.8167]
# 100% 968/968 [02:01<00:00,  7.99it/s, trn_ls=0.0415, val_ls=0.0474, val_mt=0.8500]
# 100% 968/968 [01:49<00:00,  8.83it/s, trn_ls=0.0384, val_ls=0.0461, val_mt=0.8292]
# 100% 968/968 [01:55<00:00,  8.40it/s, trn_ls=0.0356, val_ls=0.0534, val_mt=0.8042]
# 100% 968/968 [01:56<00:00,  8.33it/s, trn_ls=0.0311, val_ls=0.0491, val_mt=0.8458]
# 100% 968/968 [01:44<00:00,  9.23it/s, trn_ls=0.0300, val_ls=0.0468, val_mt=0.8458]
# 100% 968/968 [01:50<00:00,  8.78it/s, trn_ls=0.0303, val_ls=0.0384, val_mt=0.8583]
# 100% 968/968 [01:51<00:00,  8.68it/s, trn_ls=0.0293, val_ls=0.0444, val_mt=0.8500]
# 100% 968/968 [01:56<00:00,  8.32it/s, trn_ls=0.0299, val_ls=0.0458, val_mt=0.8583]

# %%
train(2)
# Out:
# Train Images: 973 Valid Images: 243
# 100% 968/968 [01:50<00:00,  8.76it/s, trn_ls=0.2315, val_ls=0.1458, val_mt=0.3000]
# 100% 968/968 [01:43<00:00,  9.39it/s, trn_ls=0.1225, val_ls=0.0965, val_mt=0.5750]
# 100% 968/968 [01:46<00:00,  9.10it/s, trn_ls=0.0950, val_ls=0.0677, val_mt=0.7292]
# 100% 968/968 [01:57<00:00,  8.22it/s, trn_ls=0.0756, val_ls=0.0707, val_mt=0.7125]
# 100% 968/968 [02:01<00:00,  7.99it/s, trn_ls=0.0638, val_ls=0.0613, val_mt=0.7500]
# 100% 968/968 [01:53<00:00,  8.54it/s, trn_ls=0.0511, val_ls=0.0452, val_mt=0.8125]
# 100% 968/968 [01:41<00:00,  9.54it/s, trn_ls=0.0468, val_ls=0.0472, val_mt=0.8167]
# 100% 968/968 [01:44<00:00,  9.22it/s, trn_ls=0.0438, val_ls=0.0509, val_mt=0.7625]
# 100% 968/968 [01:41<00:00,  9.56it/s, trn_ls=0.0389, val_ls=0.0362, val_mt=0.8542]
# 100% 968/968 [01:43<00:00,  9.31it/s, trn_ls=0.0357, val_ls=0.0416, val_mt=0.8292]
# 100% 968/968 [01:39<00:00,  9.78it/s, trn_ls=0.0332, val_ls=0.0368, val_mt=0.8708]
# 100% 968/968 [01:52<00:00,  8.62it/s, trn_ls=0.0325, val_ls=0.0411, val_mt=0.8667]
# 100% 968/968 [01:41<00:00,  9.54it/s, trn_ls=0.0308, val_ls=0.0383, val_mt=0.8667]
# 100% 968/968 [01:41<00:00,  9.50it/s, trn_ls=0.0309, val_ls=0.0388, val_mt=0.8500]
# 100% 968/968 [01:37<00:00,  9.95it/s, trn_ls=0.0305, val_ls=0.0404, val_mt=0.8375]

# %%
train(3)
# Out:
# Train Images: 973 Valid Images: 243
# 100% 968/968 [01:39<00:00,  9.70it/s, trn_ls=0.2308, val_ls=0.1387, val_mt=0.3333]
# 100% 968/968 [01:41<00:00,  9.55it/s, trn_ls=0.1226, val_ls=0.1077, val_mt=0.5458]
# 100% 968/968 [01:45<00:00,  9.15it/s, trn_ls=0.0898, val_ls=0.0676, val_mt=0.7208]
# 100% 968/968 [01:35<00:00, 10.15it/s, trn_ls=0.0738, val_ls=0.0548, val_mt=0.7958]
# 100% 968/968 [01:40<00:00,  9.64it/s, trn_ls=0.0640, val_ls=0.0631, val_mt=0.7458]
# 100% 968/968 [01:42<00:00,  9.49it/s, trn_ls=0.0493, val_ls=0.0371, val_mt=0.8292]
# 100% 968/968 [01:35<00:00, 10.16it/s, trn_ls=0.0434, val_ls=0.0341, val_mt=0.8750]
# 100% 968/968 [01:28<00:00, 10.97it/s, trn_ls=0.0407, val_ls=0.0545, val_mt=0.8083]
# 100% 968/968 [01:51<00:00,  8.66it/s, trn_ls=0.0365, val_ls=0.0299, val_mt=0.8792]
# 100% 968/968 [01:39<00:00,  9.74it/s, trn_ls=0.0349, val_ls=0.0333, val_mt=0.8667]
# 100% 968/968 [01:40<00:00,  9.64it/s, trn_ls=0.0343, val_ls=0.0357, val_mt=0.8458]
# 100% 968/968 [01:45<00:00,  9.20it/s, trn_ls=0.0319, val_ls=0.0421, val_mt=0.8458]
# 100% 968/968 [01:27<00:00, 11.00it/s, trn_ls=0.0315, val_ls=0.0337, val_mt=0.8583]
# 100% 968/968 [01:28<00:00, 10.97it/s, trn_ls=0.0310, val_ls=0.0381, val_mt=0.8667]
# 100% 968/968 [01:40<00:00,  9.59it/s, trn_ls=0.0304, val_ls=0.0291, val_mt=0.9083]

# %%
train(4)
# Out:
# Train Images: 973 Valid Images: 243
# 100% 968/968 [01:33<00:00, 10.39it/s, trn_ls=0.2283, val_ls=0.1348, val_mt=0.3333]
# 100% 968/968 [01:24<00:00, 11.48it/s, trn_ls=0.1239, val_ls=0.0958, val_mt=0.5875]
# 100% 968/968 [01:27<00:00, 11.04it/s, trn_ls=0.0927, val_ls=0.0751, val_mt=0.6917]
# 100% 968/968 [01:30<00:00, 10.72it/s, trn_ls=0.0764, val_ls=0.0703, val_mt=0.7125]
# 100% 968/968 [01:27<00:00, 11.05it/s, trn_ls=0.0672, val_ls=0.0703, val_mt=0.7583]
# 100% 968/968 [01:34<00:00, 10.22it/s, trn_ls=0.0617, val_ls=0.0516, val_mt=0.8083]
# 100% 968/968 [01:30<00:00, 10.73it/s, trn_ls=0.0503, val_ls=0.0521, val_mt=0.8292]
# 100% 968/968 [01:22<00:00, 11.80it/s, trn_ls=0.0455, val_ls=0.0627, val_mt=0.7833]
# 100% 968/968 [01:24<00:00, 11.44it/s, trn_ls=0.0393, val_ls=0.0416, val_mt=0.8292]
# 100% 968/968 [01:32<00:00, 10.46it/s, trn_ls=0.0347, val_ls=0.0349, val_mt=0.8625]
# 100% 968/968 [01:20<00:00, 11.95it/s, trn_ls=0.0329, val_ls=0.0491, val_mt=0.8250]
# 100% 968/968 [01:24<00:00, 11.40it/s, trn_ls=0.0315, val_ls=0.0369, val_mt=0.8917]
# 100% 968/968 [01:22<00:00, 11.74it/s, trn_ls=0.0287, val_ls=0.0384, val_mt=0.8583]
# 100% 968/968 [01:21<00:00, 11.92it/s, trn_ls=0.0280, val_ls=0.0315, val_mt=0.8792]
# 100% 968/968 [01:19<00:00, 12.23it/s, trn_ls=0.0283, val_ls=0.0392, val_mt=0.8708]

# %%
train(5)
# Out:
# Train Images: 973 Valid Images: 243
# 100% 968/968 [01:24<00:00, 11.40it/s, trn_ls=0.2317, val_ls=0.1375, val_mt=0.3083]
# 100% 968/968 [01:38<00:00,  9.78it/s, trn_ls=0.1188, val_ls=0.1019, val_mt=0.5583]
# 100% 968/968 [01:41<00:00,  9.49it/s, trn_ls=0.0909, val_ls=0.0701, val_mt=0.7042]
# 100% 968/968 [01:36<00:00, 10.05it/s, trn_ls=0.0721, val_ls=0.0682, val_mt=0.6667]
# 100% 968/968 [01:38<00:00,  9.79it/s, trn_ls=0.0573, val_ls=0.0456, val_mt=0.8125]
# 100% 968/968 [01:24<00:00, 11.52it/s, trn_ls=0.0508, val_ls=0.0673, val_mt=0.7583]
# 100% 968/968 [01:30<00:00, 10.65it/s, trn_ls=0.0436, val_ls=0.0451, val_mt=0.8000]
# 100% 968/968 [01:34<00:00, 10.24it/s, trn_ls=0.0415, val_ls=0.0476, val_mt=0.8083]
# 100% 968/968 [01:23<00:00, 11.56it/s, trn_ls=0.0370, val_ls=0.0390, val_mt=0.8500]
# 100% 968/968 [01:21<00:00, 11.83it/s, trn_ls=0.0359, val_ls=0.0441, val_mt=0.8458]
# 100% 968/968 [01:27<00:00, 11.00it/s, trn_ls=0.0360, val_ls=0.0461, val_mt=0.8042]
# 100% 968/968 [01:34<00:00, 10.26it/s, trn_ls=0.0335, val_ls=0.0372, val_mt=0.8792]
# 100% 968/968 [01:29<00:00, 10.79it/s, trn_ls=0.0334, val_ls=0.0451, val_mt=0.8500]
# 100% 968/968 [01:26<00:00, 11.19it/s, trn_ls=0.0326, val_ls=0.0536, val_mt=0.8083]
# 100% 968/968 [01:28<00:00, 10.88it/s, trn_ls=0.0332, val_ls=0.0490, val_mt=0.8333]
