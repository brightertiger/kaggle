# %%
import sys
sys.path.insert(0,'..')
from warnings import filterwarnings
filterwarnings("ignore")
# %load_ext autoreload
# %autosave 180
# Out:
# Autosaving every 180 seconds

# %%
# %autoreload
import os
import random
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
from torch.optim import Adam
from torch.utils.data import DataLoader
from source.version2.data import trainLoader
from source.version2.model import ResnetModel
from source.version2.train import trainModel
from source.version2.loss import CELoss
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
def seed(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True
    return None

seed(2017)

# %%
def train(fold):
    loader = {}
    loader['data'] = '../../data/positive.csv'
    loader['fold_idx'] = fold
    train, valid = trainLoader(**loader)
    params = {}
    params['batch_size'] = 8
    params['drop_last'] = True
    train = DataLoader(train, **params, num_workers=4, shuffle=True)
    valid = DataLoader(valid, **params, num_workers=0, shuffle=False)
    model = ResnetModel()
    model = model.to('cuda:0')
    optimizer = Adam(model.parameters(), lr=1e-04)
    schedular = ReduceLROnPlateau(optimizer, min_lr=1e-5, patience=0, factor=0.5)
    trainer = {}
    trainer['model'] = model
    trainer['train_data'] = train
    trainer['valid_data'] = valid
    trainer['loss_fn'] = nn.BCEWithLogitsLoss()
    trainer['optimizer'] = optimizer
    trainer['save_path'] = '../../model/version2/model_{}.pt'.format(fold)
    trainer['epochs'] = 15
    trainer['batch'] = 8
    trainer['scheduler'] = schedular
    trainModel(**trainer)
    model.cpu()
    del model
    return None

# %%
train(1)
# Out:
# Train Images: 972 Valid Images: 244
# 100% 968/968 [00:31<00:00, 30.28it/s, trn_ls=0.2350, val_ls=0.1409, val_mt=0.3125]
# 100% 968/968 [00:31<00:00, 30.78it/s, trn_ls=0.1284, val_ls=0.0941, val_mt=0.6208]
# 100% 968/968 [00:31<00:00, 31.06it/s, trn_ls=0.1065, val_ls=0.0812, val_mt=0.6875]
# 100% 968/968 [00:31<00:00, 31.13it/s, trn_ls=0.0897, val_ls=0.0683, val_mt=0.7000]
# 100% 968/968 [00:31<00:00, 31.02it/s, trn_ls=0.0774, val_ls=0.0537, val_mt=0.7833]
# 100% 968/968 [00:31<00:00, 30.99it/s, trn_ls=0.0700, val_ls=0.0524, val_mt=0.7708]
# 100% 968/968 [00:31<00:00, 30.82it/s, trn_ls=0.0631, val_ls=0.0371, val_mt=0.8625]
# 100% 968/968 [00:31<00:00, 30.37it/s, trn_ls=0.0581, val_ls=0.0460, val_mt=0.8042]
# 100% 968/968 [00:31<00:00, 31.14it/s, trn_ls=0.0536, val_ls=0.0370, val_mt=0.8542]
# 100% 968/968 [00:31<00:00, 30.99it/s, trn_ls=0.0469, val_ls=0.0490, val_mt=0.8125]
# 100% 968/968 [00:31<00:00, 30.89it/s, trn_ls=0.0449, val_ls=0.0335, val_mt=0.9042]
# 100% 968/968 [00:31<00:00, 30.84it/s, trn_ls=0.0461, val_ls=0.0412, val_mt=0.8583]
# 100% 968/968 [00:31<00:00, 30.95it/s, trn_ls=0.0448, val_ls=0.0353, val_mt=0.8750]
# 100% 968/968 [00:31<00:00, 30.85it/s, trn_ls=0.0462, val_ls=0.0363, val_mt=0.8667]
# 100% 968/968 [00:31<00:00, 30.78it/s, trn_ls=0.0465, val_ls=0.0360, val_mt=0.8708]

# %%
train(2)
# Out:
# Train Images: 973 Valid Images: 243
# 100% 968/968 [00:31<00:00, 30.75it/s, trn_ls=0.2322, val_ls=0.1400, val_mt=0.3542]
# 100% 968/968 [00:31<00:00, 30.75it/s, trn_ls=0.1316, val_ls=0.0989, val_mt=0.5542]
# 100% 968/968 [00:31<00:00, 30.68it/s, trn_ls=0.1029, val_ls=0.0651, val_mt=0.7458]
# 100% 968/968 [00:31<00:00, 31.00it/s, trn_ls=0.0857, val_ls=0.0588, val_mt=0.7667]
# 100% 968/968 [00:31<00:00, 31.08it/s, trn_ls=0.0790, val_ls=0.0666, val_mt=0.7667]
# 100% 968/968 [00:31<00:00, 30.92it/s, trn_ls=0.0693, val_ls=0.0424, val_mt=0.8708]
# 100% 968/968 [00:31<00:00, 30.89it/s, trn_ls=0.0648, val_ls=0.0467, val_mt=0.8083]
# 100% 968/968 [00:31<00:00, 30.68it/s, trn_ls=0.0574, val_ls=0.0430, val_mt=0.8208]
# 100% 968/968 [00:31<00:00, 31.03it/s, trn_ls=0.0533, val_ls=0.0277, val_mt=0.8958]
# 100% 968/968 [00:31<00:00, 30.94it/s, trn_ls=0.0500, val_ls=0.0345, val_mt=0.8708]
# 100% 968/968 [00:31<00:00, 30.68it/s, trn_ls=0.0489, val_ls=0.0315, val_mt=0.8708]
# 100% 968/968 [00:31<00:00, 30.79it/s, trn_ls=0.0479, val_ls=0.0383, val_mt=0.8667]
# 100% 968/968 [00:31<00:00, 30.78it/s, trn_ls=0.0466, val_ls=0.0361, val_mt=0.8667]
# 100% 968/968 [00:31<00:00, 30.89it/s, trn_ls=0.0467, val_ls=0.0401, val_mt=0.8542]
# 100% 968/968 [00:31<00:00, 30.81it/s, trn_ls=0.0478, val_ls=0.0438, val_mt=0.8292]

# %%
train(3)
# Out:
# Train Images: 973 Valid Images: 243
# 100% 968/968 [00:31<00:00, 30.72it/s, trn_ls=0.2313, val_ls=0.1351, val_mt=0.3833]
# 100% 968/968 [00:31<00:00, 30.91it/s, trn_ls=0.1299, val_ls=0.0924, val_mt=0.6500]
# 100% 968/968 [00:31<00:00, 31.13it/s, trn_ls=0.1007, val_ls=0.0721, val_mt=0.6750]
# 100% 968/968 [00:31<00:00, 30.75it/s, trn_ls=0.0876, val_ls=0.0490, val_mt=0.8000]
# 100% 968/968 [00:31<00:00, 30.79it/s, trn_ls=0.0766, val_ls=0.0631, val_mt=0.7417]
# 100% 968/968 [00:31<00:00, 31.13it/s, trn_ls=0.0659, val_ls=0.0370, val_mt=0.8792]
# 100% 968/968 [00:31<00:00, 31.03it/s, trn_ls=0.0598, val_ls=0.0454, val_mt=0.8292]
# 100% 968/968 [00:31<00:00, 31.00it/s, trn_ls=0.0564, val_ls=0.0358, val_mt=0.8708]
# 100% 968/968 [00:31<00:00, 31.04it/s, trn_ls=0.0532, val_ls=0.0363, val_mt=0.8417]
# 100% 968/968 [00:30<00:00, 31.24it/s, trn_ls=0.0505, val_ls=0.0250, val_mt=0.9250]
# 100% 968/968 [00:31<00:00, 31.01it/s, trn_ls=0.0507, val_ls=0.0332, val_mt=0.8792]
# 100% 968/968 [00:31<00:00, 31.11it/s, trn_ls=0.0490, val_ls=0.0323, val_mt=0.8875]
# 100% 968/968 [00:30<00:00, 31.30it/s, trn_ls=0.0498, val_ls=0.0322, val_mt=0.9125]
# 100% 968/968 [00:31<00:00, 30.89it/s, trn_ls=0.0499, val_ls=0.0327, val_mt=0.8958]
# 100% 968/968 [00:31<00:00, 31.17it/s, trn_ls=0.0489, val_ls=0.0320, val_mt=0.8958]

# %%
train(4)
# Out:
# Train Images: 973 Valid Images: 243
# 100% 968/968 [00:32<00:00, 30.13it/s, trn_ls=0.2351, val_ls=0.1450, val_mt=0.2958]
# 100% 968/968 [00:31<00:00, 30.56it/s, trn_ls=0.1279, val_ls=0.1004, val_mt=0.5042]
# 100% 968/968 [00:31<00:00, 30.57it/s, trn_ls=0.1028, val_ls=0.0738, val_mt=0.6708]
# 100% 968/968 [00:31<00:00, 30.53it/s, trn_ls=0.0865, val_ls=0.0668, val_mt=0.7292]
# 100% 968/968 [00:31<00:00, 30.48it/s, trn_ls=0.0774, val_ls=0.0442, val_mt=0.8083]
# 100% 968/968 [00:31<00:00, 30.36it/s, trn_ls=0.0686, val_ls=0.0510, val_mt=0.8292]
# 100% 968/968 [00:31<00:00, 30.58it/s, trn_ls=0.0655, val_ls=0.0582, val_mt=0.7375]
# 100% 968/968 [00:31<00:00, 30.45it/s, trn_ls=0.0602, val_ls=0.0428, val_mt=0.8292]
# 100% 968/968 [00:31<00:00, 30.75it/s, trn_ls=0.0549, val_ls=0.0486, val_mt=0.8083]
# 100% 968/968 [00:31<00:00, 30.35it/s, trn_ls=0.0493, val_ls=0.0521, val_mt=0.7958]
# 100% 968/968 [00:31<00:00, 30.45it/s, trn_ls=0.0468, val_ls=0.0390, val_mt=0.8625]
# 100% 968/968 [00:31<00:00, 30.52it/s, trn_ls=0.0456, val_ls=0.0414, val_mt=0.8625]
# 100% 968/968 [00:32<00:00, 30.16it/s, trn_ls=0.0461, val_ls=0.0400, val_mt=0.8667]
# 100% 968/968 [00:31<00:00, 30.52it/s, trn_ls=0.0457, val_ls=0.0430, val_mt=0.8458]
# 100% 968/968 [00:31<00:00, 30.63it/s, trn_ls=0.0468, val_ls=0.0349, val_mt=0.8875]

# %%
train(5)
# Out:
# Train Images: 973 Valid Images: 243
# 100% 968/968 [00:31<00:00, 30.29it/s, trn_ls=0.2315, val_ls=0.1454, val_mt=0.2542]
# 100% 968/968 [00:32<00:00, 30.09it/s, trn_ls=0.1319, val_ls=0.0911, val_mt=0.5792]
# 100% 968/968 [00:31<00:00, 30.43it/s, trn_ls=0.1041, val_ls=0.0757, val_mt=0.6958]
# 100% 968/968 [00:31<00:00, 30.48it/s, trn_ls=0.0858, val_ls=0.0674, val_mt=0.7208]
# 100% 968/968 [00:31<00:00, 30.52it/s, trn_ls=0.0755, val_ls=0.0598, val_mt=0.7625]
# 100% 968/968 [00:31<00:00, 30.49it/s, trn_ls=0.0646, val_ls=0.0617, val_mt=0.7500]
# 100% 968/968 [00:31<00:00, 30.55it/s, trn_ls=0.0558, val_ls=0.0457, val_mt=0.8042]
# 100% 968/968 [00:31<00:00, 30.46it/s, trn_ls=0.0512, val_ls=0.0492, val_mt=0.8167]
# 100% 968/968 [00:31<00:00, 30.69it/s, trn_ls=0.0514, val_ls=0.0490, val_mt=0.8333]
# 100% 968/968 [00:32<00:00, 30.23it/s, trn_ls=0.0507, val_ls=0.0443, val_mt=0.8250]
# 100% 968/968 [00:31<00:00, 30.43it/s, trn_ls=0.0474, val_ls=0.0449, val_mt=0.8167]
# 100% 968/968 [00:31<00:00, 30.33it/s, trn_ls=0.0456, val_ls=0.0458, val_mt=0.8458]
# 100% 968/968 [00:31<00:00, 30.39it/s, trn_ls=0.0465, val_ls=0.0438, val_mt=0.8250]
# 100% 968/968 [00:31<00:00, 30.66it/s, trn_ls=0.0436, val_ls=0.0351, val_mt=0.8625]
# 100% 968/968 [00:31<00:00, 30.29it/s, trn_ls=0.0452, val_ls=0.0465, val_mt=0.8333]
