# %%
import sys
sys.path.insert(0,'..')
from warnings import filterwarnings
filterwarnings("ignore")
# %load_ext autoreload
# %autosave 180
# Out:
# Autosaving every 180 seconds

# %%
# %autoreload
import os
import random
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
from torch.optim import Adam
from torch.utils.data import DataLoader
from source.version0.data import trainLoader
from source.version0.model import ResnetModel
from source.version0.train import trainModel
from source.version0.loss import CELoss
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
def seed(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True
    return None

seed(2017)

# %%
def train(fold):
    loader = {}
    loader['data'] = '../../data/positive.csv'
    loader['fold_idx'] = fold
    train, valid = trainLoader(**loader)
    params = {}
    params['batch_size'] = 8
    params['drop_last'] = True
    train = DataLoader(train, **params, num_workers=4, shuffle=True)
    valid = DataLoader(valid, **params, num_workers=0, shuffle=False)
    model = ResnetModel()
    model = model.to('cuda:0')
    optimizer = Adam(model.parameters(), lr=1e-04)
    schedular = ReduceLROnPlateau(optimizer, min_lr=1e-5, patience=0, factor=0.5)
    trainer = {}
    trainer['model'] = model
    trainer['train_data'] = train
    trainer['valid_data'] = valid
    trainer['loss_fn'] = nn.BCEWithLogitsLoss()
    trainer['optimizer'] = optimizer
    trainer['save_path'] = '../../model/version0/model_{}.pt'.format(fold)
    trainer['epochs'] = 15
    trainer['batch'] = 8
    trainer['scheduler'] = schedular
    trainModel(**trainer)
    model.cpu()
    del model
    return None

# %%
train(1)
# Out:
# Train Images: 972 Valid Images: 244
# 100% 968/968 [02:11<00:00,  7.36it/s, trn_ls=0.2348, val_ls=0.1435, val_mt=0.2292]
# 100% 968/968 [02:01<00:00,  7.98it/s, trn_ls=0.1297, val_ls=0.0969, val_mt=0.6333]
# 100% 968/968 [01:59<00:00,  8.10it/s, trn_ls=0.1055, val_ls=0.0796, val_mt=0.6458]
# 100% 968/968 [02:00<00:00,  8.01it/s, trn_ls=0.0886, val_ls=0.0702, val_mt=0.7083]
# 100% 968/968 [02:01<00:00,  7.94it/s, trn_ls=0.0765, val_ls=0.0597, val_mt=0.7833]
# 100% 968/968 [02:00<00:00,  8.01it/s, trn_ls=0.0704, val_ls=0.0494, val_mt=0.7667]
# 100% 968/968 [02:06<00:00,  7.63it/s, trn_ls=0.0609, val_ls=0.0362, val_mt=0.8708]
# 100% 968/968 [02:05<00:00,  7.72it/s, trn_ls=0.0580, val_ls=0.0430, val_mt=0.8167]
# 100% 968/968 [02:06<00:00,  7.65it/s, trn_ls=0.0540, val_ls=0.0337, val_mt=0.8833]
# 100% 968/968 [01:58<00:00,  8.17it/s, trn_ls=0.0472, val_ls=0.0485, val_mt=0.8333]
# 100% 968/968 [02:01<00:00,  7.99it/s, trn_ls=0.0445, val_ls=0.0347, val_mt=0.8917]
# 100% 968/968 [02:01<00:00,  7.99it/s, trn_ls=0.0447, val_ls=0.0402, val_mt=0.8542]
# 100% 968/968 [02:01<00:00,  7.96it/s, trn_ls=0.0445, val_ls=0.0319, val_mt=0.9000]
# 100% 968/968 [02:07<00:00,  7.60it/s, trn_ls=0.0454, val_ls=0.0321, val_mt=0.8958]
# 100% 968/968 [01:56<00:00,  8.33it/s, trn_ls=0.0456, val_ls=0.0403, val_mt=0.8458]

# %%
train(2)
# Out:
# Train Images: 973 Valid Images: 243
# 100% 968/968 [01:59<00:00,  8.08it/s, trn_ls=0.2305, val_ls=0.1394, val_mt=0.3292]
# 100% 968/968 [02:08<00:00,  7.51it/s, trn_ls=0.1295, val_ls=0.1048, val_mt=0.5167]
# 100% 968/968 [01:59<00:00,  8.09it/s, trn_ls=0.1000, val_ls=0.0622, val_mt=0.7375]
# 100% 968/968 [02:03<00:00,  7.85it/s, trn_ls=0.0842, val_ls=0.0700, val_mt=0.7250]
# 100% 968/968 [01:52<00:00,  8.63it/s, trn_ls=0.0718, val_ls=0.0537, val_mt=0.7958]
# 100% 968/968 [01:56<00:00,  8.32it/s, trn_ls=0.0644, val_ls=0.0516, val_mt=0.7875]
# 100% 968/968 [01:59<00:00,  8.13it/s, trn_ls=0.0579, val_ls=0.0402, val_mt=0.8500]
# 100% 968/968 [01:56<00:00,  8.31it/s, trn_ls=0.0540, val_ls=0.0401, val_mt=0.8542]
# 100% 968/968 [01:58<00:00,  8.15it/s, trn_ls=0.0509, val_ls=0.0335, val_mt=0.8875]
# 100% 968/968 [02:04<00:00,  7.77it/s, trn_ls=0.0507, val_ls=0.0375, val_mt=0.8667]
# 100% 968/968 [01:58<00:00,  8.16it/s, trn_ls=0.0502, val_ls=0.0371, val_mt=0.8708]
# 100% 968/968 [02:07<00:00,  7.57it/s, trn_ls=0.0470, val_ls=0.0365, val_mt=0.8667]
# 100% 968/968 [02:02<00:00,  7.90it/s, trn_ls=0.0471, val_ls=0.0445, val_mt=0.8458]
# 100% 968/968 [02:00<00:00,  8.03it/s, trn_ls=0.0467, val_ls=0.0413, val_mt=0.8708]
# 100% 968/968 [01:56<00:00,  8.28it/s, trn_ls=0.0462, val_ls=0.0417, val_mt=0.8458]

# %%
train(3)
# Out:
# Train Images: 973 Valid Images: 243
# 100% 968/968 [01:53<00:00,  8.52it/s, trn_ls=0.2317, val_ls=0.1352, val_mt=0.3917]
# 100% 968/968 [01:55<00:00,  8.37it/s, trn_ls=0.1280, val_ls=0.0931, val_mt=0.5958]
# 100% 968/968 [02:04<00:00,  7.76it/s, trn_ls=0.0988, val_ls=0.0753, val_mt=0.6625]
# 100% 968/968 [02:05<00:00,  7.69it/s, trn_ls=0.0855, val_ls=0.0514, val_mt=0.8208]
# 100% 968/968 [01:56<00:00,  8.33it/s, trn_ls=0.0690, val_ls=0.0582, val_mt=0.7708]
# 100% 968/968 [02:02<00:00,  7.90it/s, trn_ls=0.0620, val_ls=0.0337, val_mt=0.8750]
# 100% 968/968 [02:01<00:00,  7.97it/s, trn_ls=0.0569, val_ls=0.0337, val_mt=0.8833]
# 100% 968/968 [01:59<00:00,  8.10it/s, trn_ls=0.0543, val_ls=0.0378, val_mt=0.8583]
# 100% 968/968 [02:05<00:00,  7.73it/s, trn_ls=0.0511, val_ls=0.0378, val_mt=0.8667]
# 100% 968/968 [02:00<00:00,  8.07it/s, trn_ls=0.0503, val_ls=0.0279, val_mt=0.9000]
# 100% 968/968 [02:01<00:00,  7.97it/s, trn_ls=0.0491, val_ls=0.0362, val_mt=0.8708]
# 100% 968/968 [02:01<00:00,  7.96it/s, trn_ls=0.0463, val_ls=0.0375, val_mt=0.8792]
# 100% 968/968 [01:55<00:00,  8.36it/s, trn_ls=0.0452, val_ls=0.0292, val_mt=0.9083]
# 100% 968/968 [01:56<00:00,  8.31it/s, trn_ls=0.0453, val_ls=0.0391, val_mt=0.8667]
# 100% 968/968 [01:56<00:00,  8.33it/s, trn_ls=0.0470, val_ls=0.0319, val_mt=0.8625]

# %%
train(4)
# Out:
# Train Images: 973 Valid Images: 243
# 100% 968/968 [01:55<00:00,  8.38it/s, trn_ls=0.2280, val_ls=0.1365, val_mt=0.3750]
# 100% 968/968 [01:51<00:00,  8.68it/s, trn_ls=0.1276, val_ls=0.0973, val_mt=0.5542]
# 100% 968/968 [01:54<00:00,  8.46it/s, trn_ls=0.1050, val_ls=0.0774, val_mt=0.6833]
# 100% 968/968 [01:55<00:00,  8.38it/s, trn_ls=0.0870, val_ls=0.0739, val_mt=0.7167]
# 100% 968/968 [01:55<00:00,  8.37it/s, trn_ls=0.0748, val_ls=0.0677, val_mt=0.6917]
# 100% 968/968 [01:56<00:00,  8.31it/s, trn_ls=0.0644, val_ls=0.0481, val_mt=0.8292]
# 100% 968/968 [01:57<00:00,  8.25it/s, trn_ls=0.0577, val_ls=0.0470, val_mt=0.8292]
# 100% 968/968 [01:55<00:00,  8.38it/s, trn_ls=0.0548, val_ls=0.0508, val_mt=0.8125]
# 100% 968/968 [01:57<00:00,  8.23it/s, trn_ls=0.0537, val_ls=0.0422, val_mt=0.8042]
# 100% 968/968 [01:53<00:00,  8.54it/s, trn_ls=0.0496, val_ls=0.0345, val_mt=0.8708]
# 100% 968/968 [01:58<00:00,  8.19it/s, trn_ls=0.0484, val_ls=0.0483, val_mt=0.8083]
# 100% 968/968 [02:00<00:00,  8.04it/s, trn_ls=0.0480, val_ls=0.0399, val_mt=0.8542]
# 100% 968/968 [01:54<00:00,  8.47it/s, trn_ls=0.0450, val_ls=0.0472, val_mt=0.8333]
# 100% 968/968 [02:00<00:00,  8.01it/s, trn_ls=0.0465, val_ls=0.0454, val_mt=0.8208]
# 100% 968/968 [01:53<00:00,  8.51it/s, trn_ls=0.0464, val_ls=0.0452, val_mt=0.8375]

# %%
train(5)
# Out:
# Train Images: 973 Valid Images: 243
# 100% 968/968 [01:49<00:00,  8.87it/s, trn_ls=0.2330, val_ls=0.1401, val_mt=0.3208]
# 100% 968/968 [01:55<00:00,  8.35it/s, trn_ls=0.1324, val_ls=0.1049, val_mt=0.5125]
# 100% 968/968 [01:55<00:00,  8.38it/s, trn_ls=0.1069, val_ls=0.0772, val_mt=0.6708]
# 100% 968/968 [01:53<00:00,  8.53it/s, trn_ls=0.0869, val_ls=0.0822, val_mt=0.6333]
# 100% 968/968 [02:00<00:00,  8.05it/s, trn_ls=0.0721, val_ls=0.0451, val_mt=0.8500]
# 100% 968/968 [01:54<00:00,  8.46it/s, trn_ls=0.0632, val_ls=0.0634, val_mt=0.7708]
# 100% 968/968 [01:59<00:00,  8.10it/s, trn_ls=0.0566, val_ls=0.0583, val_mt=0.7875]
# 100% 968/968 [01:50<00:00,  8.77it/s, trn_ls=0.0550, val_ls=0.0468, val_mt=0.8417]
# 100% 968/968 [01:53<00:00,  8.50it/s, trn_ls=0.0549, val_ls=0.0391, val_mt=0.8750]
# 100% 968/968 [01:58<00:00,  8.16it/s, trn_ls=0.0523, val_ls=0.0439, val_mt=0.8542]
# 100% 968/968 [02:01<00:00,  7.95it/s, trn_ls=0.0494, val_ls=0.0451, val_mt=0.8500]
# 100% 968/968 [02:01<00:00,  7.99it/s, trn_ls=0.0462, val_ls=0.0464, val_mt=0.8583]
# 100% 968/968 [01:58<00:00,  8.20it/s, trn_ls=0.0496, val_ls=0.0505, val_mt=0.8292]
# 100% 968/968 [01:55<00:00,  8.38it/s, trn_ls=0.0485, val_ls=0.0542, val_mt=0.8208]
# 100% 968/968 [02:01<00:00,  7.97it/s, trn_ls=0.0478, val_ls=0.0502, val_mt=0.8292]
