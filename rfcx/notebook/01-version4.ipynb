# %%
import sys
sys.path.insert(0,'..')
from warnings import filterwarnings
filterwarnings("ignore")
# %load_ext autoreload
# %autosave 180
# Out:
# Autosaving every 180 seconds

# %%
# %autoreload
import os
import random
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
from torch.optim import Adam
from torch.utils.data import DataLoader
from source.version4.data import trainLoader
from source.version4.model import ResnetModel
from source.version4.train import trainModel
from source.version4.loss import CELoss
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
def seed(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True
    return None

seed(2017)

# %%
def train(fold):
    loader = {}
    loader['data'] = '../../data/positive.csv'
    loader['fold_idx'] = fold
    train, valid = trainLoader(**loader)
    params = {}
    params['batch_size'] = 8
    params['drop_last'] = True
    train = DataLoader(train, **params, num_workers=6, shuffle=True)
    valid = DataLoader(valid, **params, num_workers=0, shuffle=False)
    model = ResnetModel()
    model = model.to('cuda:0')
    optimizer = Adam(model.parameters(), lr=1e-04)
    schedular = ReduceLROnPlateau(optimizer, min_lr=1e-5, patience=0, factor=0.5)
    trainer = {}
    trainer['model'] = model
    trainer['train_data'] = train
    trainer['valid_data'] = valid
    trainer['loss_fn'] = nn.BCEWithLogitsLoss()
    trainer['optimizer'] = optimizer
    trainer['save_path'] = '../../model/version4/model_{}.pt'.format(fold)
    trainer['epochs'] = 15
    trainer['batch'] = 8
    trainer['scheduler'] = schedular
    trainModel(**trainer)
    model.cpu()
    del model
    return None

# %%
train(1)
# Out:
# Train Images: 972 Valid Images: 244
# 100% 968/968 [02:12<00:00,  7.33it/s, trn_ls=0.2339, val_ls=0.1502, val_mt=0.2125]
# 100% 968/968 [01:47<00:00,  9.02it/s, trn_ls=0.1320, val_ls=0.0999, val_mt=0.5833]
# 100% 968/968 [01:50<00:00,  8.74it/s, trn_ls=0.0974, val_ls=0.0835, val_mt=0.6292]
# 100% 968/968 [01:59<00:00,  8.12it/s, trn_ls=0.0789, val_ls=0.0740, val_mt=0.7208]
# 100% 968/968 [01:56<00:00,  8.29it/s, trn_ls=0.0615, val_ls=0.0522, val_mt=0.7917]
# 100% 968/968 [01:44<00:00,  9.30it/s, trn_ls=0.0529, val_ls=0.0507, val_mt=0.7750]
# 100% 968/968 [01:56<00:00,  8.33it/s, trn_ls=0.0429, val_ls=0.0443, val_mt=0.8583]
# 100% 968/968 [01:59<00:00,  8.10it/s, trn_ls=0.0384, val_ls=0.0451, val_mt=0.8500]
# 100% 968/968 [01:45<00:00,  9.20it/s, trn_ls=0.0373, val_ls=0.0420, val_mt=0.8583]
# 100% 968/968 [02:04<00:00,  7.77it/s, trn_ls=0.0320, val_ls=0.0540, val_mt=0.7958]
# 100% 968/968 [01:52<00:00,  8.63it/s, trn_ls=0.0299, val_ls=0.0422, val_mt=0.8708]
# 100% 968/968 [01:51<00:00,  8.71it/s, trn_ls=0.0299, val_ls=0.0488, val_mt=0.8375]
# 100% 968/968 [01:49<00:00,  8.85it/s, trn_ls=0.0286, val_ls=0.0398, val_mt=0.8583]
# 100% 968/968 [01:45<00:00,  9.22it/s, trn_ls=0.0282, val_ls=0.0394, val_mt=0.8708]
# 100% 968/968 [01:45<00:00,  9.15it/s, trn_ls=0.0283, val_ls=0.0400, val_mt=0.8792]

# %%
train(2)
# Out:
# Train Images: 973 Valid Images: 243
# 100% 968/968 [01:57<00:00,  8.24it/s, trn_ls=0.2292, val_ls=0.1596, val_mt=0.1708]
# 100% 968/968 [01:45<00:00,  9.20it/s, trn_ls=0.1330, val_ls=0.1135, val_mt=0.4750]
# 100% 968/968 [01:44<00:00,  9.26it/s, trn_ls=0.0953, val_ls=0.0783, val_mt=0.6500]
# 100% 968/968 [01:39<00:00,  9.74it/s, trn_ls=0.0739, val_ls=0.0628, val_mt=0.7333]
# 100% 968/968 [01:39<00:00,  9.75it/s, trn_ls=0.0577, val_ls=0.0583, val_mt=0.7583]
# 100% 968/968 [01:37<00:00,  9.89it/s, trn_ls=0.0518, val_ls=0.0506, val_mt=0.7958]
# 100% 968/968 [01:46<00:00,  9.06it/s, trn_ls=0.0493, val_ls=0.0556, val_mt=0.7958]
# 100% 968/968 [01:44<00:00,  9.25it/s, trn_ls=0.0441, val_ls=0.0397, val_mt=0.8458]
# 100% 968/968 [01:35<00:00, 10.16it/s, trn_ls=0.0420, val_ls=0.0463, val_mt=0.8042]
# 100% 968/968 [01:36<00:00, 10.01it/s, trn_ls=0.0354, val_ls=0.0413, val_mt=0.8375]
# 100% 968/968 [01:38<00:00,  9.86it/s, trn_ls=0.0322, val_ls=0.0290, val_mt=0.8875]
# 100% 968/968 [01:31<00:00, 10.58it/s, trn_ls=0.0284, val_ls=0.0398, val_mt=0.8750]
# 100% 968/968 [01:43<00:00,  9.34it/s, trn_ls=0.0298, val_ls=0.0393, val_mt=0.8667]
# 100% 968/968 [01:37<00:00,  9.96it/s, trn_ls=0.0275, val_ls=0.0402, val_mt=0.8542]
# 100% 968/968 [01:44<00:00,  9.30it/s, trn_ls=0.0287, val_ls=0.0406, val_mt=0.8417]

# %%
train(3)
# Out:
# Train Images: 973 Valid Images: 243
# 100% 968/968 [01:32<00:00, 10.43it/s, trn_ls=0.2312, val_ls=0.1493, val_mt=0.2417]
# 100% 968/968 [01:31<00:00, 10.56it/s, trn_ls=0.1299, val_ls=0.1020, val_mt=0.6083]
# 100% 968/968 [01:39<00:00,  9.75it/s, trn_ls=0.0927, val_ls=0.0655, val_mt=0.7667]
# 100% 968/968 [01:44<00:00,  9.24it/s, trn_ls=0.0726, val_ls=0.0500, val_mt=0.8083]
# 100% 968/968 [01:31<00:00, 10.61it/s, trn_ls=0.0583, val_ls=0.0614, val_mt=0.7417]
# 100% 968/968 [01:29<00:00, 10.77it/s, trn_ls=0.0489, val_ls=0.0374, val_mt=0.8875]
# 100% 968/968 [01:41<00:00,  9.50it/s, trn_ls=0.0425, val_ls=0.0359, val_mt=0.8875]
# 100% 968/968 [01:30<00:00, 10.68it/s, trn_ls=0.0384, val_ls=0.0445, val_mt=0.8542]
# 100% 968/968 [01:33<00:00, 10.34it/s, trn_ls=0.0335, val_ls=0.0416, val_mt=0.8500]
# 100% 968/968 [01:42<00:00,  9.44it/s, trn_ls=0.0305, val_ls=0.0333, val_mt=0.8875]
# 100% 968/968 [01:34<00:00, 10.25it/s, trn_ls=0.0317, val_ls=0.0410, val_mt=0.8625]
# 100% 968/968 [01:33<00:00, 10.32it/s, trn_ls=0.0298, val_ls=0.0415, val_mt=0.8458]
# 100% 968/968 [01:38<00:00,  9.86it/s, trn_ls=0.0284, val_ls=0.0354, val_mt=0.8958]
# 100% 968/968 [01:30<00:00, 10.68it/s, trn_ls=0.0287, val_ls=0.0414, val_mt=0.8500]
# 100% 968/968 [01:35<00:00, 10.14it/s, trn_ls=0.0293, val_ls=0.0343, val_mt=0.8667]

# %%
train(4)
# Out:
# Train Images: 973 Valid Images: 243
# 100% 968/968 [02:05<00:00,  7.71it/s, trn_ls=0.2344, val_ls=0.1498, val_mt=0.2875]
# 100% 968/968 [01:49<00:00,  8.82it/s, trn_ls=0.1347, val_ls=0.1165, val_mt=0.4458]
# 100% 968/968 [01:38<00:00,  9.85it/s, trn_ls=0.0994, val_ls=0.0967, val_mt=0.6208]
# 100% 968/968 [01:44<00:00,  9.29it/s, trn_ls=0.0764, val_ls=0.0608, val_mt=0.7708]
# 100% 968/968 [01:46<00:00,  9.11it/s, trn_ls=0.0617, val_ls=0.0542, val_mt=0.7958]
# 100% 968/968 [01:45<00:00,  9.19it/s, trn_ls=0.0546, val_ls=0.0629, val_mt=0.7417]
# 100% 968/968 [01:52<00:00,  8.64it/s, trn_ls=0.0436, val_ls=0.0488, val_mt=0.7958]
# 100% 968/968 [01:39<00:00,  9.78it/s, trn_ls=0.0409, val_ls=0.0604, val_mt=0.7500]
# 100% 968/968 [01:43<00:00,  9.34it/s, trn_ls=0.0362, val_ls=0.0481, val_mt=0.8083]
# 100% 968/968 [01:38<00:00,  9.85it/s, trn_ls=0.0321, val_ls=0.0425, val_mt=0.8125]
# 100% 968/968 [01:40<00:00,  9.59it/s, trn_ls=0.0314, val_ls=0.0467, val_mt=0.8208]
# 100% 968/968 [01:42<00:00,  9.44it/s, trn_ls=0.0304, val_ls=0.0382, val_mt=0.8292]
# 100% 968/968 [01:34<00:00, 10.24it/s, trn_ls=0.0284, val_ls=0.0416, val_mt=0.8208]
# 100% 968/968 [01:36<00:00, 10.05it/s, trn_ls=0.0288, val_ls=0.0431, val_mt=0.8167]
# 100% 968/968 [01:38<00:00,  9.83it/s, trn_ls=0.0264, val_ls=0.0416, val_mt=0.8375]

# %%
train(5)
# Out:
# Train Images: 973 Valid Images: 243
# 100% 968/968 [01:42<00:00,  9.43it/s, trn_ls=0.2382, val_ls=0.1539, val_mt=0.1958]
# 100% 968/968 [01:33<00:00, 10.40it/s, trn_ls=0.1346, val_ls=0.1122, val_mt=0.5000]
# 100% 968/968 [01:45<00:00,  9.18it/s, trn_ls=0.1004, val_ls=0.0815, val_mt=0.6917]
# 100% 968/968 [01:37<00:00,  9.90it/s, trn_ls=0.0757, val_ls=0.0585, val_mt=0.7875]
# 100% 968/968 [01:41<00:00,  9.51it/s, trn_ls=0.0617, val_ls=0.0542, val_mt=0.8208]
# 100% 968/968 [01:40<00:00,  9.59it/s, trn_ls=0.0525, val_ls=0.0724, val_mt=0.7417]
# 100% 968/968 [01:38<00:00,  9.83it/s, trn_ls=0.0447, val_ls=0.0623, val_mt=0.7792]
# 100% 968/968 [01:38<00:00,  9.80it/s, trn_ls=0.0374, val_ls=0.0414, val_mt=0.8375]
# 100% 968/968 [01:40<00:00,  9.59it/s, trn_ls=0.0342, val_ls=0.0390, val_mt=0.8417]
# 100% 968/968 [01:37<00:00,  9.89it/s, trn_ls=0.0324, val_ls=0.0424, val_mt=0.8500]
# 100% 968/968 [01:37<00:00,  9.88it/s, trn_ls=0.0292, val_ls=0.0424, val_mt=0.8500]
# 100% 968/968 [01:41<00:00,  9.57it/s, trn_ls=0.0269, val_ls=0.0348, val_mt=0.8792]
# 100% 968/968 [01:49<00:00,  8.85it/s, trn_ls=0.0287, val_ls=0.0492, val_mt=0.8250]
# 100% 968/968 [01:40<00:00,  9.67it/s, trn_ls=0.0278, val_ls=0.0467, val_mt=0.8417]
# 100% 968/968 [01:45<00:00,  9.15it/s, trn_ls=0.0274, val_ls=0.0453, val_mt=0.8458]
