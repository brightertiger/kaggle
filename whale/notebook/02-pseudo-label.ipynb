# %%
import sys
sys.path.insert(0,'/home/ujjwalsrao/project/kaggle-whale/python/')
# %load_ext autoreload

# %%
# %autoreload
from processing.classify.data import data_loader, score_loader, pretrain_loader
from modeling.classify.model import ResNet, Accuracy
from torch.nn import CrossEntropyLoss
from utility.optimizer import AdamW
from utility.schedular import CosineLR
from modeling.classify.train import train_model
from modeling.classify.score import score_model

# %% [markdown]
# ## Training + Validation

# %% [markdown]
# - ### 224x224 - finetune

# %%
pretrain = pretrain_loader('../../data/pretrain/image/', '../../data/pretrain/train.csv', 224, 64, False)

# %%
name = 'freeze_1_size_224'
model = ResNet(freeze=1).float().cuda()
optimizer = AdamW(model.parameters(), lr=1e-2, weight_decay=1)
schedular = CosineLR(optimizer, T_max=100, T_mult=0.98, eta_min=1e-4)
loss_fn = CrossEntropyLoss()
metric_fn = Accuracy()
load_path = None
save_path = '../../model/pseudo/experiment-1/'
epochs = 5
batch = 64

# %%
arguments = []
arguments += [name]
arguments += [model]
arguments += [pretrain]
arguments += [pretrain]
arguments += [loss_fn]
arguments += [metric_fn]
arguments += [optimizer]
arguments += [schedular]
arguments += [save_path]
arguments += [load_path]
arguments += [epochs]
arguments += [batch]

# %%
train_model(*arguments)
# Out:
# 100% 9691/9728 [00:51<00:00, 189.62it/s, trn_ac=9.74, trn_ls=8.50, val_ac=27.37, val_ls=7.67]
# 100% 9691/9728 [00:52<00:00, 186.31it/s, trn_ac=32.29, trn_ls=5.54, val_ac=51.75, val_ls=3.90]
# 100% 9691/9728 [00:52<00:00, 185.72it/s, trn_ac=52.10, trn_ls=3.84, val_ac=80.90, val_ls=2.12]
# 100% 9691/9728 [00:52<00:00, 184.22it/s, trn_ac=73.44, trn_ls=2.44, val_ac=84.14, val_ls=1.88]
# 100% 9691/9728 [00:52<00:00, 183.65it/s, trn_ac=85.88, trn_ls=1.60, val_ac=96.98, val_ls=0.85]

# %%
train, valid = data_loader('../../data/boxed/train/','../../data/raw/train.csv', 224, 64)
# Out:
# Train Images: 12766 Valid Images: 2931

# %%
name = 'freeze_1_size_224'
model = ResNet(freeze=1).float().cuda()
optimizer = AdamW(model.parameters(), lr=1e-2, weight_decay=1)
schedular = CosineLR(optimizer, T_max=100, T_mult=0.98, eta_min=1e-4)
loss_fn = CrossEntropyLoss()
metric_fn = Accuracy()
load_path = '../../model/pseudo/experiment-1/'
save_path = '../../model/pseudo/experiment-1/'
epochs = 10
batch = 64

# %%
arguments = []
arguments += [name]
arguments += [model]
arguments += [train]
arguments += [valid]
arguments += [loss_fn]
arguments += [metric_fn]
arguments += [optimizer]
arguments += [schedular]
arguments += [save_path]
arguments += [load_path]
arguments += [epochs]
arguments += [batch]

# %%
train_model(*arguments)
# Out:
# Model Loaded: Loss: 0.8511
# 100% 12766/12800 [00:46<00:00, 273.23it/s, trn_ac=21.27, trn_ls=6.93, val_ac=12.81, val_ls=7.34]
# 100% 12766/12800 [00:46<00:00, 276.71it/s, trn_ac=38.26, trn_ls=5.43, val_ac=18.04, val_ls=6.67]
# 100% 12766/12800 [00:46<00:00, 274.78it/s, trn_ac=48.86, trn_ls=4.42, val_ac=23.11, val_ls=6.08]
# 100% 12766/12800 [00:46<00:00, 274.89it/s, trn_ac=60.93, trn_ls=3.37, val_ac=33.61, val_ls=5.22]
# 100% 12766/12800 [00:46<00:00, 275.13it/s, trn_ac=73.84, trn_ls=2.44, val_ac=42.16, val_ls=4.48]
# 100% 12766/12800 [00:46<00:00, 275.02it/s, trn_ac=85.49, trn_ls=1.73, val_ac=45.20, val_ls=4.29]
# 100% 12766/12800 [00:46<00:00, 276.39it/s, trn_ac=96.34, trn_ls=1.02, val_ac=53.14, val_ls=3.93]
# 100% 12766/12800 [00:46<00:00, 275.54it/s, trn_ac=99.06, trn_ls=0.67, val_ac=56.99, val_ls=3.61]
# 100% 12766/12800 [00:46<00:00, 276.24it/s, trn_ac=99.81, trn_ls=0.47, val_ac=58.70, val_ls=3.48]
# 100% 12766/12800 [00:46<00:00, 273.94it/s, trn_ac=99.95, trn_ls=0.35, val_ac=60.25, val_ls=3.46]

# %% [markdown]
# - ### 224x224 - retrain

# %%
pretrain = pretrain_loader('../../data/pretrain/image/', '../../data/pretrain/train.csv', 224, 64, False)

# %%
name = 'freeze_3_size_224'
model = ResNet(freeze=3).float().cuda()
optimizer = AdamW(model.parameters(), lr=1e-3, weight_decay=1)
schedular = CosineLR(optimizer, T_max=100, T_mult=0.98, eta_min=1e-4)
loss_fn = CrossEntropyLoss()
metric_fn = Accuracy()
load_path = '../../model/pseudo/experiment-1/'
save_path = '../../model/pseudo/experiment-2/'
epochs = 3
batch = 64

# %%
arguments = []
arguments += [name]
arguments += [model]
arguments += [pretrain]
arguments += [pretrain]
arguments += [loss_fn]
arguments += [metric_fn]
arguments += [optimizer]
arguments += [schedular]
arguments += [save_path]
arguments += [load_path]
arguments += [epochs]
arguments += [batch]

# %%
train_model(*arguments)
# Out:
# Model Loaded: Loss: 3.4629
# 100% 9691/9728 [01:07<00:00, 214.75it/s, trn_ac=79.16, trn_ls=2.21, val_ac=92.26, val_ls=1.25]
# 100% 9691/9728 [01:07<00:00, 215.12it/s, trn_ac=90.84, trn_ls=1.17, val_ac=96.63, val_ls=0.72]
# 100% 9691/9728 [01:08<00:00, 216.46it/s, trn_ac=95.51, trn_ls=0.72, val_ac=99.09, val_ls=0.31]

# %%
train, valid = data_loader('../../data/boxed/train/','../../data/raw/train.csv', 224, 64)
# Out:
# Train Images: 12766 Valid Images: 2931

# %%
name = 'freeze_3_size_224'
model = ResNet(freeze=3).float().cuda()
optimizer = AdamW(model.parameters(), lr=1e-3, weight_decay=1)
schedular = CosineLR(optimizer, T_max=100, T_mult=0.98, eta_min=1e-4)
loss_fn = CrossEntropyLoss()
metric_fn = Accuracy()
load_path = '../../model/pseudo/experiment-1/'
save_path = '../../model/pseudo/experiment-2/'
epochs = 20
batch = 64

# %%
arguments = []
arguments += [name]
arguments += [model]
arguments += [train]
arguments += [valid]
arguments += [loss_fn]
arguments += [metric_fn]
arguments += [optimizer]
arguments += [schedular]
arguments += [save_path]
arguments += [load_path]
arguments += [epochs]
arguments += [batch]

# %%
train_model(*arguments)
# Out:
# Model Loaded: Loss: 3.4629
# 100% 12766/12800 [01:07<00:00, 218.46it/s, trn_ac=78.97, trn_ls=2.16, val_ac=39.07, val_ls=4.95]
# 100% 12766/12800 [01:07<00:00, 218.73it/s, trn_ac=82.11, trn_ls=1.77, val_ac=43.33, val_ls=4.65]
# 100% 12766/12800 [01:07<00:00, 218.66it/s, trn_ac=91.69, trn_ls=1.24, val_ac=50.38, val_ls=4.21]
# 100% 12766/12800 [01:06<00:00, 217.81it/s, trn_ac=97.90, trn_ls=0.81, val_ac=55.68, val_ls=3.84]
# 100% 12766/12800 [01:07<00:00, 217.97it/s, trn_ac=99.68, trn_ls=0.52, val_ac=60.08, val_ls=3.59]
# 100% 12766/12800 [01:07<00:00, 218.76it/s, trn_ac=99.95, trn_ls=0.36, val_ac=61.86, val_ls=3.50]
# 100% 12766/12800 [01:06<00:00, 219.45it/s, trn_ac=99.98, trn_ls=0.26, val_ac=63.72, val_ls=3.41]
# 100% 12766/12800 [01:07<00:00, 218.92it/s, trn_ac=100.00, trn_ls=0.20, val_ac=65.03, val_ls=3.34]
# 100% 12766/12800 [01:07<00:00, 218.58it/s, trn_ac=100.00, trn_ls=0.17, val_ac=65.55, val_ls=3.28]
# 100% 12766/12800 [01:07<00:00, 219.37it/s, trn_ac=100.00, trn_ls=0.16, val_ac=66.81, val_ls=3.25]
# 100% 12766/12800 [01:07<00:00, 218.37it/s, trn_ac=100.00, trn_ls=0.14, val_ac=67.40, val_ls=3.22]
# 100% 12766/12800 [01:08<00:00, 217.44it/s, trn_ac=100.00, trn_ls=0.13, val_ac=68.26, val_ls=3.18]
# 100% 12766/12800 [01:07<00:00, 218.05it/s, trn_ac=100.00, trn_ls=0.12, val_ac=68.58, val_ls=3.15]
# 100% 12766/12800 [01:07<00:00, 217.15it/s, trn_ac=100.00, trn_ls=0.11, val_ac=68.51, val_ls=3.10]
# 100% 12766/12800 [01:07<00:00, 218.50it/s, trn_ac=99.99, trn_ls=0.10, val_ac=69.54, val_ls=3.09]
# 100% 12766/12800 [01:07<00:00, 218.72it/s, trn_ac=100.00, trn_ls=0.10, val_ac=69.57, val_ls=3.04]
# 100% 12766/12800 [01:06<00:00, 218.25it/s, trn_ac=99.99, trn_ls=0.09, val_ac=68.98, val_ls=3.01]
# 100% 12766/12800 [01:06<00:00, 217.94it/s, trn_ac=100.00, trn_ls=0.08, val_ac=70.51, val_ls=3.01]
# 100% 12766/12800 [01:07<00:00, 218.55it/s, trn_ac=100.00, trn_ls=0.08, val_ac=71.05, val_ls=2.96]
# 100% 12766/12800 [01:07<00:00, 218.32it/s, trn_ac=100.00, trn_ls=0.07, val_ac=70.54, val_ls=2.96]

# %% [markdown]
# - ### 448x448 - finetune

# %%
pretrain = pretrain_loader('../../data/pretrain/image/', '../../data/pretrain/train.csv', 448, 64, False)

# %%
name = 'freeze_1_size_448'
model = ResNet(freeze=1).float().cuda()
optimizer = AdamW(model.parameters(), lr=(1e-2)/4, weight_decay=1)
schedular = CosineLR(optimizer, T_max=100, T_mult=0.98, eta_min=(1e-4)/4)
loss_fn = CrossEntropyLoss()
metric_fn = Accuracy()
load_path = '../../model/pseudo/experiment-2/'
save_path = '../../model/pseudo/experiment-3/'
epochs = 3
batch = 64

# %%
arguments = []
arguments += [name]
arguments += [model]
arguments += [pretrain]
arguments += [pretrain]
arguments += [loss_fn]
arguments += [metric_fn]
arguments += [optimizer]
arguments += [schedular]
arguments += [save_path]
arguments += [load_path]
arguments += [epochs]
arguments += [batch]

# %%
train_model(*arguments)
# Out:
# Model Loaded: Loss: 2.9555
# 100% 9691/9728 [02:44<00:00, 106.84it/s, trn_ac=57.28, trn_ls=3.79, val_ac=84.76, val_ls=1.69]
# 100% 9691/9728 [02:39<00:00, 107.88it/s, trn_ac=85.09, trn_ls=1.49, val_ac=95.88, val_ls=0.60]
# 100% 9691/9728 [02:40<00:00, 108.12it/s, trn_ac=94.37, trn_ls=0.68, val_ac=99.36, val_ls=0.17]

# %%
train, valid = data_loader('../../data/boxed/train/','../../data/raw/train.csv', 448, 64)
# Out:
# Train Images: 12766 Valid Images: 2931

# %%
name = 'freeze_1_size_448'
model = ResNet(freeze=1).float().cuda()
optimizer = AdamW(model.parameters(), lr=(1e-2)/4, weight_decay=1)
schedular = CosineLR(optimizer, T_max=100, T_mult=0.98, eta_min=(1e-4)/4)
loss_fn = CrossEntropyLoss()
metric_fn = Accuracy()
load_path = '../../model/pseudo/experiment-3/'
save_path = '../../model/pseudo/experiment-3/'
epochs = 20
batch = 64

# %%
arguments = []
arguments += [name]
arguments += [model]
arguments += [train]
arguments += [valid]
arguments += [loss_fn]
arguments += [metric_fn]
arguments += [optimizer]
arguments += [schedular]
arguments += [save_path]
arguments += [load_path]
arguments += [epochs]
arguments += [batch]

# %%
train_model(*arguments)
# Out:
# Model Loaded: Loss: 0.1738
# 100% 12766/12800 [02:22<00:00, 109.60it/s, trn_ac=50.42, trn_ls=4.45, val_ac=41.81, val_ls=4.95]
# 100% 12766/12800 [02:22<00:00, 109.22it/s, trn_ac=68.40, trn_ls=2.78, val_ac=55.90, val_ls=3.95]
# 100% 12766/12800 [02:21<00:00, 108.82it/s, trn_ac=84.81, trn_ls=1.51, val_ac=66.22, val_ls=3.23]
# 100% 12766/12800 [02:22<00:00, 108.36it/s, trn_ac=96.44, trn_ls=0.67, val_ac=73.36, val_ls=2.75]
# 100% 12766/12800 [02:22<00:00, 108.21it/s, trn_ac=99.65, trn_ls=0.30, val_ac=77.48, val_ls=2.55]
# 100% 12766/12800 [02:21<00:00, 108.96it/s, trn_ac=99.97, trn_ls=0.19, val_ac=78.72, val_ls=2.53]
# 100% 12766/12800 [02:22<00:00, 109.30it/s, trn_ac=99.99, trn_ls=0.13, val_ac=80.08, val_ls=2.51]
# 100% 12766/12800 [02:21<00:00, 109.13it/s, trn_ac=100.00, trn_ls=0.12, val_ac=80.48, val_ls=2.47]
# 100% 12766/12800 [02:22<00:00, 108.89it/s, trn_ac=100.00, trn_ls=0.10, val_ac=80.65, val_ls=2.46]
# 100% 12766/12800 [02:22<00:00, 108.91it/s, trn_ac=100.00, trn_ls=0.10, val_ac=80.96, val_ls=2.45]
# 100% 12766/12800 [02:22<00:00, 108.68it/s, trn_ac=100.00, trn_ls=0.09, val_ac=80.90, val_ls=2.45]
# 100% 12766/12800 [02:21<00:00, 108.83it/s, trn_ac=99.99, trn_ls=0.09, val_ac=80.80, val_ls=2.43]
# 100% 12766/12800 [02:21<00:00, 108.49it/s, trn_ac=100.00, trn_ls=0.08, val_ac=81.13, val_ls=2.42]
# 100% 12766/12800 [02:21<00:00, 108.85it/s, trn_ac=100.00, trn_ls=0.08, val_ac=81.17, val_ls=2.43]
# 100% 12766/12800 [02:21<00:00, 108.90it/s, trn_ac=100.00, trn_ls=0.08, val_ac=81.17, val_ls=2.42]
# 100% 12766/12800 [02:21<00:00, 108.85it/s, trn_ac=100.00, trn_ls=0.08, val_ac=81.03, val_ls=2.41]
# 100% 12766/12800 [02:21<00:00, 109.08it/s, trn_ac=100.00, trn_ls=0.07, val_ac=81.50, val_ls=2.39]
# 100% 12766/12800 [02:21<00:00, 108.78it/s, trn_ac=100.00, trn_ls=0.07, val_ac=81.21, val_ls=2.39]
# 100% 12766/12800 [02:22<00:00, 109.11it/s, trn_ac=100.00, trn_ls=0.07, val_ac=81.13, val_ls=2.39]
# 100% 12766/12800 [02:23<00:00, 108.79it/s, trn_ac=100.00, trn_ls=0.07, val_ac=81.30, val_ls=2.39]

# %% [markdown]
# - ### 448x448 - upsample

# %%
pretrain = pretrain_loader('../../data/pretrain/image/', '../../data/pretrain/train.csv', 448, 64, True)

# %%
name = 'freeze_1_size_448'
model = ResNet(freeze=1).float().cuda()
optimizer = AdamW(model.parameters(), lr=(5e-3)/4, weight_decay=1)
schedular = CosineLR(optimizer, T_max=100, T_mult=0.98, eta_min=(1e-5)/4)
loss_fn = CrossEntropyLoss()
metric_fn = Accuracy()
load_path = '../../model/pseudo/experiment-3/'
save_path = '../../model/pseudo/experiment-4/'
epochs = 3
batch = 64

# %%
arguments = []
arguments += [name]
arguments += [model]
arguments += [pretrain]
arguments += [pretrain]
arguments += [loss_fn]
arguments += [metric_fn]
arguments += [optimizer]
arguments += [schedular]
arguments += [save_path]
arguments += [load_path]
arguments += [epochs]
arguments += [batch]

# %%
train_model(*arguments)
# Out:
# Model Loaded: Loss: 2.386
# 100% 9691/9728 [02:40<00:00, 107.24it/s, trn_ac=87.38, trn_ls=1.98, val_ac=94.35, val_ls=0.99]
# 100% 9691/9728 [02:40<00:00, 107.85it/s, trn_ac=95.66, trn_ls=0.75, val_ac=98.18, val_ls=0.35]
# 100% 9691/9728 [02:40<00:00, 107.59it/s, trn_ac=98.62, trn_ls=0.30, val_ac=99.53, val_ls=0.13]

# %%
train, valid = data_loader('../../data/boxed/train/','../../data/raw/train.csv', 448, 64, True, True)
# Out:
# Train Images: 12766 Valid Images: 2931

# %%
name = 'freeze_1_size_448'
model = ResNet(freeze=1).float().cuda()
optimizer = AdamW(model.parameters(), lr=(5e-3)/4, weight_decay=1)
schedular = CosineLR(optimizer, T_max=100, T_mult=0.98, eta_min=(1e-5)/4)
loss_fn = CrossEntropyLoss()
metric_fn = Accuracy()
load_path = '../../model/pseudo/experiment-4/'
save_path = '../../model/pseudo/experiment-4/'
epochs = 10
batch = 64

# %%
arguments = []
arguments += [name]
arguments += [model]
arguments += [train]
arguments += [valid]
arguments += [loss_fn]
arguments += [metric_fn]
arguments += [optimizer]
arguments += [schedular]
arguments += [save_path]
arguments += [load_path]
arguments += [epochs]
arguments += [batch]

# %%
train_model(*arguments)
# Out:
# Model Loaded: Loss: 0.1318
# 100% 12766/12800 [02:22<00:00, 108.40it/s, trn_ac=74.10, trn_ls=3.42, val_ac=64.52, val_ls=4.08]
# 100% 12766/12800 [02:22<00:00, 108.57it/s, trn_ac=88.75, trn_ls=1.67, val_ac=73.90, val_ls=3.15]
# 100% 12766/12800 [02:21<00:00, 109.17it/s, trn_ac=96.73, trn_ls=0.69, val_ac=80.29, val_ls=2.58]
# 100% 12766/12800 [02:22<00:00, 108.97it/s, trn_ac=98.94, trn_ls=0.33, val_ac=83.75, val_ls=2.35]
# 100% 12766/12800 [02:22<00:00, 108.87it/s, trn_ac=99.74, trn_ls=0.19, val_ac=84.77, val_ls=2.25]
# 100% 12766/12800 [02:22<00:00, 108.83it/s, trn_ac=99.94, trn_ls=0.13, val_ac=85.88, val_ls=2.26]
# 100% 12766/12800 [02:22<00:00, 108.88it/s, trn_ac=99.95, trn_ls=0.11, val_ac=86.70, val_ls=2.18]
# 100% 12766/12800 [02:22<00:00, 108.85it/s, trn_ac=100.00, trn_ls=0.09, val_ac=87.07, val_ls=2.17]
# 100% 12766/12800 [02:22<00:00, 108.70it/s, trn_ac=100.00, trn_ls=0.09, val_ac=87.31, val_ls=2.15]
# 100% 12766/12800 [02:22<00:00, 108.09it/s, trn_ac=100.00, trn_ls=0.08, val_ac=87.07, val_ls=2.13]

# %% [markdown]
# ## Training + Scoring

# %% [markdown]
# - ### 224x224 - finetune

# %%
pretrain = pretrain_loader('../../data/pretrain/image/', '../../data/pretrain/train.csv', 224, 64, False)

# %%
name = 'freeze_1_size_224'
model = ResNet(freeze=1).float().cuda()
optimizer = AdamW(model.parameters(), lr=1e-2, weight_decay=1)
schedular = CosineLR(optimizer, T_max=100, T_mult=0.98, eta_min=1e-4)
loss_fn = CrossEntropyLoss()
metric_fn = Accuracy()
load_path = None
save_path = '../../model/pseudo/experiment-5/'
epochs = 5
batch = 64

# %%
arguments = []
arguments += [name]
arguments += [model]
arguments += [pretrain]
arguments += [pretrain]
arguments += [loss_fn]
arguments += [metric_fn]
arguments += [optimizer]
arguments += [schedular]
arguments += [save_path]
arguments += [load_path]
arguments += [epochs]
arguments += [batch]

# %%
train_model(*arguments)
# Out:
# 100% 9691/9728 [00:50<00:00, 190.72it/s, trn_ac=9.22, trn_ls=8.43, val_ac=26.24, val_ls=7.68]
# 100% 9691/9728 [00:52<00:00, 183.81it/s, trn_ac=30.01, trn_ls=5.66, val_ac=46.02, val_ls=4.23]
# 100% 9691/9728 [00:52<00:00, 184.60it/s, trn_ac=49.59, trn_ls=4.01, val_ac=79.09, val_ls=2.34]
# 100% 9691/9728 [00:51<00:00, 187.82it/s, trn_ac=71.01, trn_ls=2.60, val_ac=86.24, val_ls=1.76]
# 100% 9691/9728 [00:52<00:00, 185.37it/s, trn_ac=84.44, trn_ls=1.70, val_ac=96.25, val_ls=0.95]

# %%
train, valid = data_loader('../../data/boxed/train/','../../data/raw/train.csv', 224, 64, False, False)
# Out:
# Train Images: 15697 Valid Images: 2931

# %%
name = 'freeze_1_size_224'
model = ResNet(freeze=1).float().cuda()
optimizer = AdamW(model.parameters(), lr=1e-2, weight_decay=1)
schedular = CosineLR(optimizer, T_max=100, T_mult=0.98, eta_min=1e-4)
loss_fn = CrossEntropyLoss()
metric_fn = Accuracy()
load_path = '../../model/pseudo/experiment-5/'
save_path = '../../model/pseudo/experiment-5/'
epochs = 10
batch = 64

# %%
arguments = []
arguments += [name]
arguments += [model]
arguments += [train]
arguments += [valid]
arguments += [loss_fn]
arguments += [metric_fn]
arguments += [optimizer]
arguments += [schedular]
arguments += [save_path]
arguments += [load_path]
arguments += [epochs]
arguments += [batch]

# %%
train_model(*arguments)
# Out:
# Model Loaded: Loss: 0.9528
# 100% 15697/15744 [00:53<00:00, 294.63it/s, trn_ac=18.13, trn_ls=7.11, val_ac=17.15, val_ls=6.60]
# 100% 15697/15744 [00:53<00:00, 291.70it/s, trn_ac=36.05, trn_ls=5.40, val_ac=41.60, val_ls=4.55]
# 100% 15697/15744 [00:54<00:00, 288.47it/s, trn_ac=49.05, trn_ls=4.24, val_ac=72.80, val_ls=2.82]
# 100% 15697/15744 [00:53<00:00, 294.89it/s, trn_ac=63.28, trn_ls=3.16, val_ac=91.04, val_ls=1.71]
# 100% 15697/15744 [00:53<00:00, 292.82it/s, trn_ac=78.42, trn_ls=2.19, val_ac=98.06, val_ls=0.90]
# 100% 15697/15744 [00:53<00:00, 291.15it/s, trn_ac=90.88, trn_ls=1.43, val_ac=99.52, val_ls=0.54]
# 100% 15697/15744 [00:53<00:00, 293.46it/s, trn_ac=97.40, trn_ls=0.89, val_ac=99.90, val_ls=0.28]
# 100% 15697/15744 [00:54<00:00, 289.87it/s, trn_ac=99.48, trn_ls=0.59, val_ac=99.93, val_ls=0.22]
# 100% 15697/15744 [00:54<00:00, 289.40it/s, trn_ac=99.83, trn_ls=0.42, val_ac=100.00, val_ls=0.15]
# 100% 15697/15744 [00:53<00:00, 293.03it/s, trn_ac=99.93, trn_ls=0.34, val_ac=100.00, val_ls=0.13]

# %% [markdown]
# - ### 224x224 - retrain

# %%
pretrain = pretrain_loader('../../data/pretrain/image/', '../../data/pretrain/train.csv', 224, 64, False)

# %%
name = 'freeze_1_size_224'
model = ResNet(freeze=3).float().cuda()
optimizer = AdamW(model.parameters(), lr=1e-3, weight_decay=1)
schedular = CosineLR(optimizer, T_max=100, T_mult=0.98, eta_min=1e-4)
loss_fn = CrossEntropyLoss()
metric_fn = Accuracy()
load_path = '../../model/pseudo/experiment-5/'
save_path = '../../model/pseudo/experiment-6/'
epochs = 3
batch = 64

# %%
arguments = []
arguments += [name]
arguments += [model]
arguments += [pretrain]
arguments += [pretrain]
arguments += [loss_fn]
arguments += [metric_fn]
arguments += [optimizer]
arguments += [schedular]
arguments += [save_path]
arguments += [load_path]
arguments += [epochs]
arguments += [batch]

# %%
train_model(*arguments)
# Out:
# Model Loaded: Loss: 0.1325
# 100% 9691/9728 [01:06<00:00, 214.36it/s, trn_ac=87.11, trn_ls=1.71, val_ac=96.56, val_ls=0.82]
# 100% 9691/9728 [01:07<00:00, 214.83it/s, trn_ac=95.05, trn_ls=0.81, val_ac=98.72, val_ls=0.44]
# 100% 9691/9728 [01:08<00:00, 214.74it/s, trn_ac=98.05, trn_ls=0.46, val_ac=99.79, val_ls=0.20]

# %%
train, valid = data_loader('../../data/boxed/train/','../../data/raw/train.csv', 224, 64)
# Out:
# Train Images: 12766 Valid Images: 2931

# %%
name = 'freeze_1_size_224'
model = ResNet(freeze=3).float().cuda()
optimizer = AdamW(model.parameters(), lr=1e-3, weight_decay=1)
schedular = CosineLR(optimizer, T_max=100, T_mult=0.98, eta_min=1e-4)
loss_fn = CrossEntropyLoss()
metric_fn = Accuracy()
load_path = '../../model/pseudo/experiment-6/'
save_path = '../../model/pseudo/experiment-6/'
epochs = 20
batch = 64

# %%
arguments = []
arguments += [name]
arguments += [model]
arguments += [train]
arguments += [valid]
arguments += [loss_fn]
arguments += [metric_fn]
arguments += [optimizer]
arguments += [schedular]
arguments += [save_path]
arguments += [load_path]
arguments += [epochs]
arguments += [batch]

# %%
train_model(*arguments)
# Out:
# Model Loaded: Loss: 0.1971
# 100% 12766/12800 [01:07<00:00, 217.29it/s, trn_ac=62.20, trn_ls=3.42, val_ac=61.14, val_ls=3.79]
# 100% 12766/12800 [01:07<00:00, 216.46it/s, trn_ac=73.48, trn_ls=2.45, val_ac=66.57, val_ls=3.16]
# 100% 12766/12800 [01:07<00:00, 217.58it/s, trn_ac=83.82, trn_ls=1.70, val_ac=76.18, val_ls=2.61]
# 100% 12766/12800 [01:07<00:00, 217.35it/s, trn_ac=94.35, trn_ls=1.11, val_ac=84.72, val_ls=2.17]
# 100% 12766/12800 [01:07<00:00, 217.57it/s, trn_ac=98.84, trn_ls=0.71, val_ac=88.48, val_ls=1.90]
# 100% 12766/12800 [01:07<00:00, 216.65it/s, trn_ac=99.84, trn_ls=0.48, val_ac=90.42, val_ls=1.78]
# 100% 12766/12800 [01:07<00:00, 217.50it/s, trn_ac=99.98, trn_ls=0.33, val_ac=92.03, val_ls=1.70]
# 100% 12766/12800 [01:07<00:00, 216.88it/s, trn_ac=100.00, trn_ls=0.25, val_ac=92.40, val_ls=1.65]
# 100% 12766/12800 [01:08<00:00, 217.50it/s, trn_ac=100.00, trn_ls=0.20, val_ac=92.75, val_ls=1.60]
# 100% 12766/12800 [01:07<00:00, 217.94it/s, trn_ac=100.00, trn_ls=0.18, val_ac=92.86, val_ls=1.60]
# 100% 12766/12800 [01:07<00:00, 217.24it/s, trn_ac=100.00, trn_ls=0.15, val_ac=92.85, val_ls=1.62]
# 100% 12766/12800 [01:07<00:00, 216.72it/s, trn_ac=100.00, trn_ls=0.14, val_ac=92.92, val_ls=1.56]
# 100% 12766/12800 [01:06<00:00, 217.92it/s, trn_ac=99.99, trn_ls=0.13, val_ac=92.77, val_ls=1.55]
# 100% 12766/12800 [01:07<00:00, 217.32it/s, trn_ac=100.00, trn_ls=0.12, val_ac=92.41, val_ls=1.56]
# 100% 12766/12800 [01:07<00:00, 217.83it/s, trn_ac=100.00, trn_ls=0.11, val_ac=92.74, val_ls=1.57]
# 100% 12766/12800 [01:06<00:00, 217.55it/s, trn_ac=100.00, trn_ls=0.10, val_ac=92.17, val_ls=1.56]
# 100% 12766/12800 [01:07<00:00, 217.98it/s, trn_ac=100.00, trn_ls=0.09, val_ac=92.19, val_ls=1.54]
# 100% 12766/12800 [01:06<00:00, 216.96it/s, trn_ac=100.00, trn_ls=0.08, val_ac=91.79, val_ls=1.56]
# 100% 12766/12800 [01:07<00:00, 217.16it/s, trn_ac=100.00, trn_ls=0.08, val_ac=91.72, val_ls=1.56]
# 100% 12766/12800 [01:07<00:00, 218.25it/s, trn_ac=99.99, trn_ls=0.07, val_ac=91.74, val_ls=1.53]

# %% [markdown]
# - ### 448x448 - finetune

# %%
pretrain = pretrain_loader('../../data/pretrain/image/', '../../data/pretrain/train.csv', 448, 64, False)

# %%
name = 'freeze_1_size_448'
model = ResNet(freeze=1).float().cuda()
optimizer = AdamW(model.parameters(), lr=(1e-2)/4, weight_decay=1)
schedular = CosineLR(optimizer, T_max=100, T_mult=0.98, eta_min=(1e-4)/4)
loss_fn = CrossEntropyLoss()
metric_fn = Accuracy()
load_path = '../../model/pseudo/experiment-6/'
save_path = '../../model/pseudo/experiment-7/'
epochs = 3
batch = 64

# %%
arguments = []
arguments += [name]
arguments += [model]
arguments += [pretrain]
arguments += [pretrain]
arguments += [loss_fn]
arguments += [metric_fn]
arguments += [optimizer]
arguments += [schedular]
arguments += [save_path]
arguments += [load_path]
arguments += [epochs]
arguments += [batch]

# %%
train_model(*arguments)
# Out:
# Model Loaded: Loss: 1.5327
# 100% 9691/9728 [02:41<00:00, 108.06it/s, trn_ac=61.54, trn_ls=3.50, val_ac=87.46, val_ls=1.42]
# 100% 9691/9728 [02:40<00:00, 108.61it/s, trn_ac=86.93, trn_ls=1.31, val_ac=96.47, val_ls=0.50]
# 100% 9691/9728 [02:40<00:00, 108.11it/s, trn_ac=95.51, trn_ls=0.57, val_ac=99.69, val_ls=0.13]

# %%
train, valid = data_loader('../../data/boxed/train/','../../data/raw/train.csv', 448, 64, False, False)
# Out:
# Train Images: 15697 Valid Images: 2931

# %%
name = 'freeze_1_size_448'
model = ResNet(freeze=1).float().cuda()
optimizer = AdamW(model.parameters(), lr=(1e-2)/4, weight_decay=1)
schedular = CosineLR(optimizer, T_max=100, T_mult=0.98, eta_min=(1e-4)/4)
loss_fn = CrossEntropyLoss()
metric_fn = Accuracy()
load_path = '../../model/pseudo/experiment-7/'
save_path = '../../model/pseudo/experiment-7/'
epochs = 15
batch = 64

# %%
arguments = []
arguments += [name]
arguments += [model]
arguments += [train]
arguments += [valid]
arguments += [loss_fn]
arguments += [metric_fn]
arguments += [optimizer]
arguments += [schedular]
arguments += [save_path]
arguments += [load_path]
arguments += [epochs]
arguments += [batch]

# %%
train_model(*arguments)
# Out:
# Model Loaded: Loss: 0.1252
# 100% 15697/15744 [02:48<00:00, 106.12it/s, trn_ac=50.38, trn_ls=4.47, val_ac=69.34, val_ls=2.97]
# 100% 15697/15744 [02:48<00:00, 106.46it/s, trn_ac=75.25, trn_ls=2.33, val_ac=96.03, val_ls=0.89]
# 100% 15697/15744 [02:47<00:00, 106.61it/s, trn_ac=89.92, trn_ls=1.17, val_ac=99.76, val_ls=0.23]
# 100% 15697/15744 [02:48<00:00, 106.44it/s, trn_ac=97.40, trn_ls=0.54, val_ac=100.00, val_ls=0.10]
# 100% 15697/15744 [02:47<00:00, 106.58it/s, trn_ac=99.62, trn_ls=0.28, val_ac=100.00, val_ls=0.07]
# 100% 15697/15744 [02:49<00:00, 106.30it/s, trn_ac=99.96, trn_ls=0.19, val_ac=100.00, val_ls=0.06]
# 100% 15697/15744 [02:47<00:00, 106.71it/s, trn_ac=99.99, trn_ls=0.15, val_ac=100.00, val_ls=0.06]
# 100% 15697/15744 [02:49<00:00, 106.80it/s, trn_ac=100.00, trn_ls=0.13, val_ac=100.00, val_ls=0.05]
# 100% 15697/15744 [02:47<00:00, 105.50it/s, trn_ac=100.00, trn_ls=0.11, val_ac=100.00, val_ls=0.05]
# 100% 15697/15744 [02:47<00:00, 106.40it/s, trn_ac=100.00, trn_ls=0.10, val_ac=100.00, val_ls=0.05]
# 100% 15697/15744 [02:48<00:00, 106.26it/s, trn_ac=100.00, trn_ls=0.10, val_ac=100.00, val_ls=0.05]
# 100% 15697/15744 [02:47<00:00, 106.76it/s, trn_ac=99.99, trn_ls=0.10, val_ac=100.00, val_ls=0.04]
# 100% 15697/15744 [02:48<00:00, 106.63it/s, trn_ac=100.00, trn_ls=0.09, val_ac=100.00, val_ls=0.04]
# 100% 15697/15744 [02:48<00:00, 106.87it/s, trn_ac=100.00, trn_ls=0.09, val_ac=100.00, val_ls=0.04]
# 100% 15697/15744 [02:48<00:00, 106.22it/s, trn_ac=100.00, trn_ls=0.09, val_ac=100.00, val_ls=0.04]

# %% [markdown]
# - ### 448x448 - upsample

# %%
pretrain = pretrain_loader('../../data/pretrain/image/', '../../data/pretrain/train.csv', 448, 64, True)

# %%
name = 'freeze_1_size_448'
model = ResNet(freeze=1).float().cuda()
optimizer = AdamW(model.parameters(), lr=(5e-3)/4, weight_decay=1)
schedular = CosineLR(optimizer, T_max=100, T_mult=0.98, eta_min=(1e-5)/4)
loss_fn = CrossEntropyLoss()
metric_fn = Accuracy()
load_path = '../../model/pseudo/experiment-7/'
save_path = '../../model/pseudo/experiment-8/'
epochs = 3
batch = 64

# %%
arguments = []
arguments += [name]
arguments += [model]
arguments += [pretrain]
arguments += [pretrain]
arguments += [loss_fn]
arguments += [metric_fn]
arguments += [optimizer]
arguments += [schedular]
arguments += [save_path]
arguments += [load_path]
arguments += [epochs]
arguments += [batch]

# %%
train_model(*arguments)
# Out:
# Model Loaded: Loss: 0.0402
# 100% 9691/9728 [02:41<00:00, 108.12it/s, trn_ac=92.66, trn_ls=1.60, val_ac=95.20, val_ls=0.80]
# 100% 9691/9728 [02:41<00:00, 108.27it/s, trn_ac=97.07, trn_ls=0.59, val_ac=98.97, val_ls=0.28]
# 100% 9691/9728 [02:41<00:00, 108.14it/s, trn_ac=99.12, trn_ls=0.23, val_ac=99.68, val_ls=0.10]

# %%
train, valid = data_loader('../../data/boxed/train/','../../data/raw/train.csv', 448, 64, False, True)
# Out:
# Train Images: 15697 Valid Images: 2931

# %%
name = 'freeze_1_size_448'
model = ResNet(freeze=1).float().cuda()
optimizer = AdamW(model.parameters(), lr=(5e-3)/4, weight_decay=1)
schedular = CosineLR(optimizer, T_max=100, T_mult=0.98, eta_min=(1e-5)/4)
loss_fn = CrossEntropyLoss()
metric_fn = Accuracy()
load_path = '../../model/pseudo/experiment-8/'
save_path = '../../model/pseudo/experiment-8/'
epochs = 10
batch = 64

# %%
arguments = []
arguments += [name]
arguments += [model]
arguments += [train]
arguments += [valid]
arguments += [loss_fn]
arguments += [metric_fn]
arguments += [optimizer]
arguments += [schedular]
arguments += [save_path]
arguments += [load_path]
arguments += [epochs]
arguments += [batch]

# %%
train_model(*arguments)
# Out:
# Model Loaded: Loss: 0.0963
# 100% 15697/15744 [02:48<00:00, 106.52it/s, trn_ac=74.28, trn_ls=3.39, val_ac=90.02, val_ls=1.63]
# 100% 15697/15744 [02:49<00:00, 106.85it/s, trn_ac=90.90, trn_ls=1.43, val_ac=97.89, val_ls=0.54]
# 100% 15697/15744 [02:49<00:00, 105.50it/s, trn_ac=97.45, trn_ls=0.57, val_ac=99.69, val_ls=0.18]
# 100% 15697/15744 [02:48<00:00, 106.53it/s, trn_ac=99.45, trn_ls=0.26, val_ac=99.90, val_ls=0.10]
# 100% 15697/15744 [02:48<00:00, 107.46it/s, trn_ac=99.91, trn_ls=0.17, val_ac=99.93, val_ls=0.07]
# 100% 15697/15744 [02:47<00:00, 105.44it/s, trn_ac=99.92, trn_ls=0.13, val_ac=99.93, val_ls=0.06]
# 100% 15697/15744 [02:47<00:00, 106.97it/s, trn_ac=99.96, trn_ls=0.11, val_ac=99.97, val_ls=0.05]
# 100% 15697/15744 [02:48<00:00, 107.06it/s, trn_ac=99.99, trn_ls=0.10, val_ac=99.97, val_ls=0.04]
# 100% 15697/15744 [02:48<00:00, 107.43it/s, trn_ac=99.96, trn_ls=0.09, val_ac=99.97, val_ls=0.04]
# 100% 15697/15744 [02:48<00:00, 107.43it/s, trn_ac=99.98, trn_ls=0.09, val_ac=99.97, val_ls=0.04]

# %% [markdown]
# - ### scoring

# %%
data = score_loader('../../data/boxed/test/', 448, 16, True)
# Out:
# Score Images: 7960

# %%
model = ResNet(freeze=False).float().cuda()

# %%
score_model(model, data, 16, '../../model/pseudo/experiment-8/', 5)
# Out:
# Model Loaded: Loss: 0.0366
# 100% 7960/7968 [00:58<00:00, 135.53it/s]
# Records: 7960
# 100% 7960/7968 [00:58<00:00, 135.65it/s]
# Records: 15920
# 100% 7960/7968 [00:58<00:00, 135.75it/s]
# Records: 23880
# 100% 7960/7968 [00:58<00:00, 135.75it/s]
# Records: 31840
# 100% 7960/7968 [00:58<00:00, 135.62it/s]
# Records: 39800
