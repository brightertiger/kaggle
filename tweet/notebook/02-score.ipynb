# %%
import sys
sys.path.insert(0,'..')
# %load_ext autoreload
# %autosave 180
# Out:
# Autosaving every 180 seconds

# %%
import numpy as np
import torch
import torch.nn as nn
from torch.optim.lr_scheduler import ReduceLROnPlateau
from transformers.optimization import AdamW
from source.version1.data import trainLoader
from source.version1.model import Model

# %%
def score(subset):
    _, valid = trainLoader(subset)
    model = Model()
    weights = torch.load('../../model/model_{}.pt'.format(subset), map_location='cpu')
    weights = weights['model_state_dict']
    model.load_state_dict(weights)
    model = model.to('cuda:0')
    save = '../../model/test_{}.csv'.format(subset)
    scoreModel(model, valid, save)
    return None

# %%
score(0)
# Out:
# (2748, 4)
